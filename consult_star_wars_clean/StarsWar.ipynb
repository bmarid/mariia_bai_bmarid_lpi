# %%
#import libraries
import requests
import pandas as pd
import numpy as np
import seaborn as sns

# %%
r = requests.get('http://swapi.dev/api/')
r.json()
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %% [markdown]
# Get Full Data of a type (people, planets, vehicles...)

# %%
#function to store all the data
def get_full_type_data(base_url):
    data =  requests.get(base_url)
    all_data = []
    data_num = 0
    for i in range(100):
        if data_num < data.json()['count']+1:
            trial=requests.get(base_url+str(i))
            if str(trial) != '<Response [404]>':
                all_data.append(trial.json())
                data_num+=1
    all_data = pd.json_normalize(all_data)
    return all_data

# %%
#function to make column numeric
def df_columns_to_numeric(df,columns):
    for column_i in columns:
        unusual_index_list = df.index[df[column_i].str.contains("\D")].tolist()
        # Rule out the unusual charactor in a numeric column
        if len(unusual_index_list)>0:
            df.loc[unusual_index_list,column_i]=np.nan
        df[column_i]=pd.to_numeric(df[column_i])
    return df

# %% [markdown]
# PEOPLE

# %%
#get and store the people data
people = get_full_type_data('https://swapi.dev/api/people/')

# %%
people
# Out:
#                name height mass hair_color    skin_color      eye_color  \
# 0    Luke Skywalker    172   77      blond          fair           blue
# 1             C-3PO    167   75        n/a          gold         yellow
# 2             R2-D2     96   32        n/a   white, blue            red
# 3       Darth Vader    202  136       none         white         yellow
# 4       Leia Organa    150   49      brown         light          brown
# ..              ...    ...  ...        ...           ...            ...
# 77         Grievous    216  159       none  brown, white  green, yellow
# 78          Tarfful    234  136      brown         brown           blue
# 79  Raymus Antilles    188   79      brown         light          brown
# 80        Sly Moore    178   48       none          pale          white
# 81       Tion Medon    206   80       none          grey          black
#
#    birth_year  gender                          homeworld  \
# 0       19BBY    male   https://swapi.dev/api/planets/1/
# 1      112BBY     n/a   https://swapi.dev/api/planets/1/
# 2       33BBY     n/a   https://swapi.dev/api/planets/8/
# 3     41.9BBY    male   https://swapi.dev/api/planets/1/
# 4       19BBY  female   https://swapi.dev/api/planets/2/
# ..        ...     ...                                ...
# 77    unknown    male  https://swapi.dev/api/planets/59/
# 78    unknown    male  https://swapi.dev/api/planets/14/
# 79    unknown    male   https://swapi.dev/api/planets/2/
# 80    unknown  female  https://swapi.dev/api/planets/60/
# 81    unknown    male  https://swapi.dev/api/planets/12/
#
#                                                 films  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2   [https://swapi.dev/api/films/1/, https://swapi...
# 3   [https://swapi.dev/api/films/1/, https://swapi...
# 4   [https://swapi.dev/api/films/1/, https://swapi...
# ..                                                ...
# 77                   [https://swapi.dev/api/films/6/]
# 78                   [https://swapi.dev/api/films/6/]
# 79  [https://swapi.dev/api/films/1/, https://swapi...
# 80  [https://swapi.dev/api/films/5/, https://swapi...
# 81                   [https://swapi.dev/api/films/6/]
#
#                                 species  \
# 0                                    []
# 1    [https://swapi.dev/api/species/2/]
# 2    [https://swapi.dev/api/species/2/]
# 3                                    []
# 4                                    []
# ..                                  ...
# 77  [https://swapi.dev/api/species/36/]
# 78   [https://swapi.dev/api/species/3/]
# 79                                   []
# 80                                   []
# 81  [https://swapi.dev/api/species/37/]
#
#                                              vehicles  \
# 0   [https://swapi.dev/api/vehicles/14/, https://s...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                [https://swapi.dev/api/vehicles/30/]
# ..                                                ...
# 77               [https://swapi.dev/api/vehicles/60/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                                             starships  \
# 0   [https://swapi.dev/api/starships/12/, https://...
# 1                                                  []
# 2                                                  []
# 3               [https://swapi.dev/api/starships/13/]
# 4                                                  []
# ..                                                ...
# 77              [https://swapi.dev/api/starships/74/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                         created                       edited  \
# 0   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# ..                          ...                          ...
# 77  2014-12-20T19:43:53.348000Z  2014-12-20T21:17:50.488000Z
# 78  2014-12-20T19:46:34.209000Z  2014-12-20T21:17:50.491000Z
# 79  2014-12-20T19:49:35.583000Z  2014-12-20T21:17:50.493000Z
# 80  2014-12-20T20:18:37.619000Z  2014-12-20T21:17:50.496000Z
# 81  2014-12-20T20:35:04.260000Z  2014-12-20T21:17:50.498000Z
#
#                                  url
# 0    https://swapi.dev/api/people/1/
# 1    https://swapi.dev/api/people/2/
# 2    https://swapi.dev/api/people/3/
# 3    https://swapi.dev/api/people/4/
# 4    https://swapi.dev/api/people/5/
# ..                               ...
# 77  https://swapi.dev/api/people/79/
# 78  https://swapi.dev/api/people/80/
# 79  https://swapi.dev/api/people/81/
# 80  https://swapi.dev/api/people/82/
# 81  https://swapi.dev/api/people/83/
#
# [82 rows x 16 columns]

# %%
#return columns name
people.columns
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'gender', 'homeworld', 'films', 'species', 'vehicles',
#        'starships', 'created', 'edited', 'url'],
#       dtype='object')

# %%
# add 3 columns about the number of films , vehicles , starships
people['film_num']=people['films'].apply(lambda x:len(x))
people['vehicles_num']=people['vehicles'].apply(lambda x:len(x))
people['starships_num']=people['starships'].apply(lambda x:len(x))
people
# Out:
#                name height mass hair_color    skin_color      eye_color  \
# 0    Luke Skywalker    172   77      blond          fair           blue
# 1             C-3PO    167   75        n/a          gold         yellow
# 2             R2-D2     96   32        n/a   white, blue            red
# 3       Darth Vader    202  136       none         white         yellow
# 4       Leia Organa    150   49      brown         light          brown
# ..              ...    ...  ...        ...           ...            ...
# 77         Grievous    216  159       none  brown, white  green, yellow
# 78          Tarfful    234  136      brown         brown           blue
# 79  Raymus Antilles    188   79      brown         light          brown
# 80        Sly Moore    178   48       none          pale          white
# 81       Tion Medon    206   80       none          grey          black
#
#    birth_year  gender                          homeworld  \
# 0       19BBY    male   https://swapi.dev/api/planets/1/
# 1      112BBY     n/a   https://swapi.dev/api/planets/1/
# 2       33BBY     n/a   https://swapi.dev/api/planets/8/
# 3     41.9BBY    male   https://swapi.dev/api/planets/1/
# 4       19BBY  female   https://swapi.dev/api/planets/2/
# ..        ...     ...                                ...
# 77    unknown    male  https://swapi.dev/api/planets/59/
# 78    unknown    male  https://swapi.dev/api/planets/14/
# 79    unknown    male   https://swapi.dev/api/planets/2/
# 80    unknown  female  https://swapi.dev/api/planets/60/
# 81    unknown    male  https://swapi.dev/api/planets/12/
#
#                                                 films  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2   [https://swapi.dev/api/films/1/, https://swapi...
# 3   [https://swapi.dev/api/films/1/, https://swapi...
# 4   [https://swapi.dev/api/films/1/, https://swapi...
# ..                                                ...
# 77                   [https://swapi.dev/api/films/6/]
# 78                   [https://swapi.dev/api/films/6/]
# 79  [https://swapi.dev/api/films/1/, https://swapi...
# 80  [https://swapi.dev/api/films/5/, https://swapi...
# 81                   [https://swapi.dev/api/films/6/]
#
#                                 species  \
# 0                                    []
# 1    [https://swapi.dev/api/species/2/]
# 2    [https://swapi.dev/api/species/2/]
# 3                                    []
# 4                                    []
# ..                                  ...
# 77  [https://swapi.dev/api/species/36/]
# 78   [https://swapi.dev/api/species/3/]
# 79                                   []
# 80                                   []
# 81  [https://swapi.dev/api/species/37/]
#
#                                              vehicles  \
# 0   [https://swapi.dev/api/vehicles/14/, https://s...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                [https://swapi.dev/api/vehicles/30/]
# ..                                                ...
# 77               [https://swapi.dev/api/vehicles/60/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                                             starships  \
# 0   [https://swapi.dev/api/starships/12/, https://...
# 1                                                  []
# 2                                                  []
# 3               [https://swapi.dev/api/starships/13/]
# 4                                                  []
# ..                                                ...
# 77              [https://swapi.dev/api/starships/74/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                         created                       edited  \
# 0   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# ..                          ...                          ...
# 77  2014-12-20T19:43:53.348000Z  2014-12-20T21:17:50.488000Z
# 78  2014-12-20T19:46:34.209000Z  2014-12-20T21:17:50.491000Z
# 79  2014-12-20T19:49:35.583000Z  2014-12-20T21:17:50.493000Z
# 80  2014-12-20T20:18:37.619000Z  2014-12-20T21:17:50.496000Z
# 81  2014-12-20T20:35:04.260000Z  2014-12-20T21:17:50.498000Z
#
#                                  url  film_num  vehicles_num  starships_num
# 0    https://swapi.dev/api/people/1/         4             2              2
# 1    https://swapi.dev/api/people/2/         6             0              0
# 2    https://swapi.dev/api/people/3/         6             0              0
# 3    https://swapi.dev/api/people/4/         4             0              1
# 4    https://swapi.dev/api/people/5/         4             1              0
# ..                               ...       ...           ...            ...
# 77  https://swapi.dev/api/people/79/         1             1              1
# 78  https://swapi.dev/api/people/80/         1             0              0
# 79  https://swapi.dev/api/people/81/         2             0              0
# 80  https://swapi.dev/api/people/82/         2             0              0
# 81  https://swapi.dev/api/people/83/         1             0              0
#
# [82 rows x 19 columns]

# %%
#see the last 3 rows
people.tail(3)
# Out:
#                name height mass hair_color skin_color eye_color birth_year  \
# 79  Raymus Antilles    188   79      brown      light     brown    unknown
# 80        Sly Moore    178   48       none       pale     white    unknown
# 81       Tion Medon    206   80       none       grey     black    unknown
#
#     gender                          homeworld  \
# 79    male   https://swapi.dev/api/planets/2/
# 80  female  https://swapi.dev/api/planets/60/
# 81    male  https://swapi.dev/api/planets/12/
#
#                                                 films  \
# 79  [https://swapi.dev/api/films/1/, https://swapi...
# 80  [https://swapi.dev/api/films/5/, https://swapi...
# 81                   [https://swapi.dev/api/films/6/]
#
#                                 species vehicles starships  \
# 79                                   []       []        []
# 80                                   []       []        []
# 81  [https://swapi.dev/api/species/37/]       []        []
#
#                         created                       edited  \
# 79  2014-12-20T19:49:35.583000Z  2014-12-20T21:17:50.493000Z
# 80  2014-12-20T20:18:37.619000Z  2014-12-20T21:17:50.496000Z
# 81  2014-12-20T20:35:04.260000Z  2014-12-20T21:17:50.498000Z
#
#                                  url  film_num  vehicles_num  starships_num
# 79  https://swapi.dev/api/people/81/         2             0              0
# 80  https://swapi.dev/api/people/82/         2             0              0
# 81  https://swapi.dev/api/people/83/         1             0              0

# %%
#get dataset info
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           82 non-null     object
#  1   height         82 non-null     object
#  2   mass           82 non-null     object
#  3   hair_color     82 non-null     object
#  4   skin_color     82 non-null     object
#  5   eye_color      82 non-null     object
#  6   birth_year     82 non-null     object
#  7   gender         82 non-null     object
#  8   homeworld      82 non-null     object
#  9   films          82 non-null     object
#  10  species        82 non-null     object
#  11  vehicles       82 non-null     object
#  12  starships      82 non-null     object
#  13  created        82 non-null     object
#  14  edited         82 non-null     object
#  15  url            82 non-null     object
#  16  film_num       82 non-null     int64
#  17  vehicles_num   82 non-null     int64
#  18  starships_num  82 non-null     int64
# dtypes: int64(3), object(16)
# memory usage: 12.3+ KB

# %%
# change the mass and height columns tybe to numeric type
people = df_columns_to_numeric(people,['height','mass'])

# %%
#describe the final data
people.describe()
# Out:
#            height        mass   film_num  vehicles_num  starships_num
# count   81.000000   56.000000  82.000000     82.000000      82.000000
# mean   174.604938   75.875000   1.975610      0.158537       0.365854
# std     34.774157   29.661155   1.305029      0.429456       0.839050
# min     66.000000   15.000000   1.000000      0.000000       0.000000
# 25%    167.000000   55.000000   1.000000      0.000000       0.000000
# 50%    180.000000   79.000000   1.000000      0.000000       0.000000
# 75%    191.000000   84.250000   3.000000      0.000000       0.000000
# max    264.000000  159.000000   6.000000      2.000000       5.000000

# %%
people = people.drop(columns=['created', 'edited'])

# %%
# Find the greatest mass and the name og who has it
print(people.iloc[people['mass'].idxmax()]['name'],people['mass'].max())
# Out:
# Grievous 159.0

# %%
#find the number of empty values in each column
#26 in mass and 1 in heigh
people.isnull().sum()
# Out:
# name              0
# height            1
# mass             26
# hair_color        0
# skin_color        0
# eye_color         0
# birth_year        0
# gender            0
# homeworld         0
# films             0
# species           0
# vehicles          0
# starships         0
# url               0
# film_num          0
# vehicles_num      0
# starships_num     0
# dtype: int64

# %%
#find all kindes of skin
people['skin_color'].unique()
# Out:
# array(['fair', 'gold', 'white, blue', 'white', 'light', 'white, red',
#        'unknown', 'green', 'green-tan, brown', 'pale', 'metal', 'dark',
#        'brown mottle', 'brown', 'grey', 'mottled green', 'orange',
#        'blue, grey', 'grey, red', 'red', 'blue', 'grey, blue',
#        'grey, green, yellow', 'yellow', 'tan', 'fair, green, yellow',
#        'silver, red', 'green, grey', 'red, blue, white', 'brown, white'],
#       dtype=object)

# %%
#replace the missing values to np.nan to make it more understandable
missing_values=['??','na','X','999999']
people=people.replace(missing_values,np.NaN)
people
# Out:
#                name  height   mass hair_color    skin_color      eye_color  \
# 0    Luke Skywalker   172.0   77.0      blond          fair           blue
# 1             C-3PO   167.0   75.0        n/a          gold         yellow
# 2             R2-D2    96.0   32.0        n/a   white, blue            red
# 3       Darth Vader   202.0  136.0       none         white         yellow
# 4       Leia Organa   150.0   49.0      brown         light          brown
# ..              ...     ...    ...        ...           ...            ...
# 77         Grievous   216.0  159.0       none  brown, white  green, yellow
# 78          Tarfful   234.0  136.0      brown         brown           blue
# 79  Raymus Antilles   188.0   79.0      brown         light          brown
# 80        Sly Moore   178.0   48.0       none          pale          white
# 81       Tion Medon   206.0   80.0       none          grey          black
#
#    birth_year  gender                          homeworld  \
# 0       19BBY    male   https://swapi.dev/api/planets/1/
# 1      112BBY     n/a   https://swapi.dev/api/planets/1/
# 2       33BBY     n/a   https://swapi.dev/api/planets/8/
# 3     41.9BBY    male   https://swapi.dev/api/planets/1/
# 4       19BBY  female   https://swapi.dev/api/planets/2/
# ..        ...     ...                                ...
# 77    unknown    male  https://swapi.dev/api/planets/59/
# 78    unknown    male  https://swapi.dev/api/planets/14/
# 79    unknown    male   https://swapi.dev/api/planets/2/
# 80    unknown  female  https://swapi.dev/api/planets/60/
# 81    unknown    male  https://swapi.dev/api/planets/12/
#
#                                                 films  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2   [https://swapi.dev/api/films/1/, https://swapi...
# 3   [https://swapi.dev/api/films/1/, https://swapi...
# 4   [https://swapi.dev/api/films/1/, https://swapi...
# ..                                                ...
# 77                   [https://swapi.dev/api/films/6/]
# 78                   [https://swapi.dev/api/films/6/]
# 79  [https://swapi.dev/api/films/1/, https://swapi...
# 80  [https://swapi.dev/api/films/5/, https://swapi...
# 81                   [https://swapi.dev/api/films/6/]
#
#                                 species  \
# 0                                    []
# 1    [https://swapi.dev/api/species/2/]
# 2    [https://swapi.dev/api/species/2/]
# 3                                    []
# 4                                    []
# ..                                  ...
# 77  [https://swapi.dev/api/species/36/]
# 78   [https://swapi.dev/api/species/3/]
# 79                                   []
# 80                                   []
# 81  [https://swapi.dev/api/species/37/]
#
#                                              vehicles  \
# 0   [https://swapi.dev/api/vehicles/14/, https://s...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                [https://swapi.dev/api/vehicles/30/]
# ..                                                ...
# 77               [https://swapi.dev/api/vehicles/60/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                                             starships  \
# 0   [https://swapi.dev/api/starships/12/, https://...
# 1                                                  []
# 2                                                  []
# 3               [https://swapi.dev/api/starships/13/]
# 4                                                  []
# ..                                                ...
# 77              [https://swapi.dev/api/starships/74/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                                  url  film_num  vehicles_num  starships_num
# 0    https://swapi.dev/api/people/1/         4             2              2
# 1    https://swapi.dev/api/people/2/         6             0              0
# 2    https://swapi.dev/api/people/3/         6             0              0
# 3    https://swapi.dev/api/people/4/         4             0              1
# 4    https://swapi.dev/api/people/5/         4             1              0
# ..                               ...       ...           ...            ...
# 77  https://swapi.dev/api/people/79/         1             1              1
# 78  https://swapi.dev/api/people/80/         1             0              0
# 79  https://swapi.dev/api/people/81/         2             0              0
# 80  https://swapi.dev/api/people/82/         2             0              0
# 81  https://swapi.dev/api/people/83/         1             0              0
#
# [82 rows x 17 columns]

# %%
#fill the empty values in mass and height columns with the mean and median values of all data
m=people["mass"].mean()
h=people["height"].median()
people["mass"].fillna(m,inplace=True)
people["height"].fillna(h,inplace=True)
people["height"]
# Out:
# 0     172.0
# 1     167.0
# 2      96.0
# 3     202.0
# 4     150.0
#       ...
# 77    216.0
# 78    234.0
# 79    188.0
# 80    178.0
# 81    206.0
# Name: height, Length: 82, dtype: float64

# %%
# sort data by mass and height columns in ascending for mass...and show the first of the data
people.sort_values(by=["mass", "height"], ascending=[True, False]).head()
# Out:
#                      name  height  mass hair_color   skin_color eye_color  \
# 45           Ratts Tyerel    79.0  15.0       none   grey, blue   unknown
# 18                   Yoda    66.0  17.0      white        green     brown
# 28  Wicket Systri Warrick    88.0  20.0      brown        brown     brown
# 7                   R5-D4    97.0  32.0        n/a   white, red       red
# 2                   R2-D2    96.0  32.0        n/a  white, blue       red
#
#    birth_year gender                          homeworld  \
# 45    unknown   male  https://swapi.dev/api/planets/38/
# 18     896BBY   male  https://swapi.dev/api/planets/28/
# 28       8BBY   male   https://swapi.dev/api/planets/7/
# 7     unknown    n/a   https://swapi.dev/api/planets/1/
# 2       33BBY    n/a   https://swapi.dev/api/planets/8/
#
#                                                 films  \
# 45                   [https://swapi.dev/api/films/4/]
# 18  [https://swapi.dev/api/films/2/, https://swapi...
# 28                   [https://swapi.dev/api/films/3/]
# 7                    [https://swapi.dev/api/films/1/]
# 2   [https://swapi.dev/api/films/1/, https://swapi...
#
#                                 species vehicles starships  \
# 45  [https://swapi.dev/api/species/16/]       []        []
# 18   [https://swapi.dev/api/species/6/]       []        []
# 28   [https://swapi.dev/api/species/9/]       []        []
# 7    [https://swapi.dev/api/species/2/]       []        []
# 2    [https://swapi.dev/api/species/2/]       []        []
#
#                                  url  film_num  vehicles_num  starships_num
# 45  https://swapi.dev/api/people/47/         1             0              0
# 18  https://swapi.dev/api/people/20/         5             0              0
# 28  https://swapi.dev/api/people/30/         1             0              0
# 7    https://swapi.dev/api/people/8/         1             0              0
# 2    https://swapi.dev/api/people/3/         6             0              0

# %%
#find the male people with brown skin color
people[(people["gender"] == 'male') & (people["skin_color"] == "brown")]['name']
# Out:
# 28    Wicket Systri Warrick
# 52                Eeth Koth
# 69          Dexter Jettster
# 78                  Tarfful
# Name: name, dtype: object

# %%
top_home_world_people = people[people['homeworld']=='https://swapi.dev/api/planets/20/']
top_home_world_people
# Out:
#              name  height  mass     hair_color skin_color  eye_color  \
# 9  Obi-Wan Kenobi   182.0  77.0  auburn, white       fair  blue-gray
#
#   birth_year gender                          homeworld  \
# 9      57BBY   male  https://swapi.dev/api/planets/20/
#
#                                                films species  \
# 9  [https://swapi.dev/api/films/1/, https://swapi...      []
#
#                                vehicles  \
# 9  [https://swapi.dev/api/vehicles/38/]
#
#                                            starships  \
# 9  [https://swapi.dev/api/starships/48/, https://...
#
#                                 url  film_num  vehicles_num  starships_num
# 9  https://swapi.dev/api/people/10/         6             1              5

# %% [markdown]
# PLANETS

# %%
planets = requests.get('http://swapi.dev/api/planets')

planets.json()
# Out:
# {'count': 60,
#  'next': 'https://swapi.dev/api/planets/?page=2',
#  'previous': None,
#  'results': [{'name': 'Tatooine',
#    'rotation_period': '23',
#    'orbital_period': '304',
#    'diameter': '10465',
#    'climate': 'arid',
#    'gravity': '1 standard',
#    'terrain': 'desert',
#    'surface_water': '1',
#    'population': '200000',
#    'residents': ['https://swapi.dev/api/people/1/',
#     'https://swapi.dev/api/people/2/',
#     'https://swapi.dev/api/people/4/',
#     'https://swapi.dev/api/people/6/',
#     'https://swapi.dev/api/people/7/',
#     'https://swapi.dev/api/people/8/',
#     'https://swapi.dev/api/people/9/',
#     'https://swapi.dev/api/people/11/',
#     'https://swapi.dev/api/people/43/',
#     'https://swapi.dev/api/people/62/'],
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/4/',
#     'https://swapi.dev/api/films/5/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-09T13:50:49.641000Z',
#    'edited': '2014-12-20T20:58:18.411000Z',
#    'url': 'https://swapi.dev/api/planets/1/'},
#   {'name': 'Alderaan',
#    'rotation_period': '24',
#    'orbital_period': '364',
#    'diameter': '12500',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'grasslands, mountains',
#    'surface_water': '40',
#    'population': '2000000000',
#    'residents': ['https://swapi.dev/api/people/5/',
#     'https://swapi.dev/api/people/68/',
#     'https://swapi.dev/api/people/81/'],
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-10T11:35:48.479000Z',
#    'edited': '2014-12-20T20:58:18.420000Z',
#    'url': 'https://swapi.dev/api/planets/2/'},
#   {'name': 'Yavin IV',
#    'rotation_period': '24',
#    'orbital_period': '4818',
#    'diameter': '10200',
#    'climate': 'temperate, tropical',
#    'gravity': '1 standard',
#    'terrain': 'jungle, rainforests',
#    'surface_water': '8',
#    'population': '1000',
#    'residents': [],
#    'films': ['https://swapi.dev/api/films/1/'],
#    'created': '2014-12-10T11:37:19.144000Z',
#    'edited': '2014-12-20T20:58:18.421000Z',
#    'url': 'https://swapi.dev/api/planets/3/'},
#   {'name': 'Hoth',
#    'rotation_period': '23',
#    'orbital_period': '549',
#    'diameter': '7200',
#    'climate': 'frozen',
#    'gravity': '1.1 standard',
#    'terrain': 'tundra, ice caves, mountain ranges',
#    'surface_water': '100',
#    'population': 'unknown',
#    'residents': [],
#    'films': ['https://swapi.dev/api/films/2/'],
#    'created': '2014-12-10T11:39:13.934000Z',
#    'edited': '2014-12-20T20:58:18.423000Z',
#    'url': 'https://swapi.dev/api/planets/4/'},
#   {'name': 'Dagobah',
#    'rotation_period': '23',
#    'orbital_period': '341',
#    'diameter': '8900',
#    'climate': 'murky',
#    'gravity': 'N/A',
#    'terrain': 'swamp, jungles',
#    'surface_water': '8',
#    'population': 'unknown',
#    'residents': [],
#    'films': ['https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-10T11:42:22.590000Z',
#    'edited': '2014-12-20T20:58:18.425000Z',
#    'url': 'https://swapi.dev/api/planets/5/'},
#   {'name': 'Bespin',
#    'rotation_period': '12',
#    'orbital_period': '5110',
#    'diameter': '118000',
#    'climate': 'temperate',
#    'gravity': '1.5 (surface), 1 standard (Cloud City)',
#    'terrain': 'gas giant',
#    'surface_water': '0',
#    'population': '6000000',
#    'residents': ['https://swapi.dev/api/people/26/'],
#    'films': ['https://swapi.dev/api/films/2/'],
#    'created': '2014-12-10T11:43:55.240000Z',
#    'edited': '2014-12-20T20:58:18.427000Z',
#    'url': 'https://swapi.dev/api/planets/6/'},
#   {'name': 'Endor',
#    'rotation_period': '18',
#    'orbital_period': '402',
#    'diameter': '4900',
#    'climate': 'temperate',
#    'gravity': '0.85 standard',
#    'terrain': 'forests, mountains, lakes',
#    'surface_water': '8',
#    'population': '30000000',
#    'residents': ['https://swapi.dev/api/people/30/'],
#    'films': ['https://swapi.dev/api/films/3/'],
#    'created': '2014-12-10T11:50:29.349000Z',
#    'edited': '2014-12-20T20:58:18.429000Z',
#    'url': 'https://swapi.dev/api/planets/7/'},
#   {'name': 'Naboo',
#    'rotation_period': '26',
#    'orbital_period': '312',
#    'diameter': '12120',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'grassy hills, swamps, forests, mountains',
#    'surface_water': '12',
#    'population': '4500000000',
#    'residents': ['https://swapi.dev/api/people/3/',
#     'https://swapi.dev/api/people/21/',
#     'https://swapi.dev/api/people/35/',
#     'https://swapi.dev/api/people/36/',
#     'https://swapi.dev/api/people/37/',
#     'https://swapi.dev/api/people/38/',
#     'https://swapi.dev/api/people/39/',
#     'https://swapi.dev/api/people/42/',
#     'https://swapi.dev/api/people/60/',
#     'https://swapi.dev/api/people/61/',
#     'https://swapi.dev/api/people/66/'],
#    'films': ['https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/4/',
#     'https://swapi.dev/api/films/5/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-10T11:52:31.066000Z',
#    'edited': '2014-12-20T20:58:18.430000Z',
#    'url': 'https://swapi.dev/api/planets/8/'},
#   {'name': 'Coruscant',
#    'rotation_period': '24',
#    'orbital_period': '368',
#    'diameter': '12240',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'cityscape, mountains',
#    'surface_water': 'unknown',
#    'population': '1000000000000',
#    'residents': ['https://swapi.dev/api/people/34/',
#     'https://swapi.dev/api/people/55/',
#     'https://swapi.dev/api/people/74/'],
#    'films': ['https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/4/',
#     'https://swapi.dev/api/films/5/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-10T11:54:13.921000Z',
#    'edited': '2014-12-20T20:58:18.432000Z',
#    'url': 'https://swapi.dev/api/planets/9/'},
#   {'name': 'Kamino',
#    'rotation_period': '27',
#    'orbital_period': '463',
#    'diameter': '19720',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'ocean',
#    'surface_water': '100',
#    'population': '1000000000',
#    'residents': ['https://swapi.dev/api/people/22/',
#     'https://swapi.dev/api/people/72/',
#     'https://swapi.dev/api/people/73/'],
#    'films': ['https://swapi.dev/api/films/5/'],
#    'created': '2014-12-10T12:45:06.577000Z',
#    'edited': '2014-12-20T20:58:18.434000Z',
#    'url': 'https://swapi.dev/api/planets/10/'}]}

# %%
planets = get_full_type_data('http://swapi.dev/api/planets/')
print("Number of planets",planets.shape[0])
# Out:
# Number of planets 60

# %%
planets.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population  \
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           N/A                      swamp, jungles             8     unknown
#
#                                            residents  \
# 0  [https://swapi.dev/api/people/1/, https://swap...
# 1  [https://swapi.dev/api/people/5/, https://swap...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2                   [https://swapi.dev/api/films/1/]
# 3                   [https://swapi.dev/api/films/2/]
# 4  [https://swapi.dev/api/films/2/, https://swapi...
#
#                        created                       edited  \
# 0  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 1  2014-12-10T11:35:48.479000Z  2014-12-20T20:58:18.420000Z
# 2  2014-12-10T11:37:19.144000Z  2014-12-20T20:58:18.421000Z
# 3  2014-12-10T11:39:13.934000Z  2014-12-20T20:58:18.423000Z
# 4  2014-12-10T11:42:22.590000Z  2014-12-20T20:58:18.425000Z
#
#                                 url
# 0  https://swapi.dev/api/planets/1/
# 1  https://swapi.dev/api/planets/2/
# 2  https://swapi.dev/api/planets/3/
# 3  https://swapi.dev/api/planets/4/
# 4  https://swapi.dev/api/planets/5/

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             60 non-null     object
#  1   rotation_period  60 non-null     object
#  2   orbital_period   60 non-null     object
#  3   diameter         60 non-null     object
#  4   climate          60 non-null     object
#  5   gravity          60 non-null     object
#  6   terrain          60 non-null     object
#  7   surface_water    60 non-null     object
#  8   population       60 non-null     object
#  9   residents        60 non-null     object
#  10  films            60 non-null     object
#  11  created          60 non-null     object
#  12  edited           60 non-null     object
#  13  url              60 non-null     object
# dtypes: object(14)
# memory usage: 6.7+ KB

# %%
#find  the planets which has temperate climate and how many surface_water for each one
planets.loc[planets.climate.str.contains('temperate'), 'surface_water']
# Out:
# 1          40
# 2           8
# 5           0
# 6           8
# 7          12
# 8     unknown
# 9         100
# 10          5
# 11        0.9
# 14          0
# 17    unknown
# 19    unknown
# 21         70
# 23    unknown
# 24    unknown
# 25         98
# 26         10
# 30        100
# 31         40
# 33    unknown
# 34    unknown
# 35    unknown
# 36          5
# 38    unknown
# 41    unknown
# 42         20
# 43         80
# 48    unknown
# 49    unknown
# 55    unknown
# 56         25
# 57    unknown
# 58    unknown
# Name: surface_water, dtype: object

# %%
#sort plantes by population
planets.sort_values(by="population", ascending=False)
# Out:
#               name  rotation_period  orbital_period       diameter  \
# 8        Coruscant        24.000000         368.000   12240.000000
# 55           Skako        27.000000         384.000   12388.340909
# 10        Geonosis        30.000000         256.000   11370.000000
# 50          Mirial        25.958333         577.625   12388.340909
# 37     Aleen Minor        25.958333         577.625   12388.340909
# 39         Troiken        25.958333         577.625   12388.340909
# 44        Iridonia        29.000000         413.000   12388.340909
# 45         Tholoth        25.958333         577.625   12388.340909
# 46         Iktotch        22.000000         481.000   12388.340909
# 47         Quermia        25.958333         577.625   12388.340909
# 48           Dorin        22.000000         409.000   13400.000000
# 59          Umbara        25.958333         577.625   12388.340909
# 27             NaN         0.000000           0.000       0.000000
# 51         Serenno        25.958333         577.625   12388.340909
# 52    Concord Dawn        25.958333         577.625   12388.340909
# 53           Zolan        25.958333         577.625   12388.340909
# 4          Dagobah        23.000000         341.000    8900.000000
# 3             Hoth        23.000000         549.000    7200.000000
# 57           Shili        25.958333         577.625   12388.340909
# 19         Stewjon        25.958333         577.625       0.000000
# 30        Mon Cala        21.000000         398.000   11030.000000
# 20          Eriadu        24.000000         360.000   13490.000000
# 32         Sullust        20.000000         263.000   12780.000000
# 23       Nal Hutta        87.000000         413.000   12150.000000
# 56      Muunilinst        28.000000         412.000   13800.000000
# 7            Naboo        26.000000         312.000   12120.000000
# 58           Kalee        23.000000         378.000   13850.000000
# 26     Ord Mantell        26.000000         334.000   14050.000000
# 49        Champala        27.000000         318.000   12388.340909
# 21        Corellia        25.000000         329.000   11000.000000
# 34       Malastare        26.000000         201.000   18880.000000
# 1         Alderaan        24.000000         364.000   12500.000000
# 36          Ryloth        30.000000         305.000   10600.000000
# 18       Saleucami        26.000000         392.000   14920.000000
# 22           Rodia        29.000000         305.000    7549.000000
# 31       Chandrila        20.000000         368.000   13500.000000
# 9           Kamino        27.000000         463.000   19720.000000
# 54            Ojom        25.958333         577.625   12388.340909
# 43     Glee Anselm        33.000000         206.000   15600.000000
# 42           Cerea        27.000000         386.000   12388.340909
# 38         Vulpter        22.000000         391.000   14900.000000
# 29         Socorro        20.000000         326.000       0.000000
# 11          Utapau        27.000000         351.000   12900.000000
# 25      Bestine IV        26.000000         680.000    6400.000000
# 13        Kashyyyk        26.000000         381.000   12765.000000
# 28       Trandosha        25.000000         371.000       0.000000
# 6            Endor        18.000000         402.000    4900.000000
# 15         Mygeeto        12.000000         167.000   10088.000000
# 33        Toydaria        21.000000         184.000    7900.000000
# 17  Cato Neimoidia        25.000000         278.000       0.000000
# 16         Felucia        34.000000         231.000    9100.000000
# 5           Bespin        12.000000        5110.000  118000.000000
# 14     Polis Massa        24.000000         590.000       0.000000
# 41      Haruun Kal        25.000000         383.000   10120.000000
# 0         Tatooine        23.000000         304.000   10465.000000
# 12        Mustafar        36.000000         412.000    4200.000000
# 35        Dathomir        24.000000         491.000   10480.000000
# 2         Yavin IV        24.000000        4818.000   10200.000000
# 24       Dantooine        25.000000         378.000    9830.000000
# 40            Tund        48.000000        1770.000   12190.000000
#
#                       climate                                 gravity  \
# 8                   temperate                              1 standard
# 55                  temperate                                       1
# 10            temperate, arid                            0.9 standard
# 50                        NaN                                     NaN
# 37                        NaN                                     NaN
# 39                        NaN                                     NaN
# 44                        NaN                                     NaN
# 45                        NaN                                     NaN
# 46         arid, rocky, windy                                       1
# 47                        NaN                                     NaN
# 48                  temperate                                       1
# 59                        NaN                                     NaN
# 27                        NaN                                     NaN
# 51                        NaN                                     NaN
# 52                        NaN                                     NaN
# 53                        NaN                                     NaN
# 4                       murky                                     N/A
# 3                      frozen                            1.1 standard
# 57                  temperate                                       1
# 19                  temperate                              1 standard
# 30                  temperate                                       1
# 20                   polluted                              1 standard
# 32                superheated                                       1
# 23                  temperate                              1 standard
# 56                  temperate                                       1
# 7                   temperate                              1 standard
# 58  arid, temperate, tropical                                       1
# 26                  temperate                              1 standard
# 49                  temperate                                       1
# 21                  temperate                              1 standard
# 34  arid, temperate, tropical                                    1.56
# 1                   temperate                              1 standard
# 36  temperate, arid, subartic                                       1
# 18                        hot                                     NaN
# 22                        hot                              1 standard
# 31                  temperate                                       1
# 9                   temperate                              1 standard
# 54                     frigid                                     NaN
# 43        tropical, temperate                                       1
# 42                  temperate                                       1
# 38           temperate, artic                                       1
# 29                       arid                              1 standard
# 11     temperate, arid, windy                              1 standard
# 25                  temperate                                     NaN
# 13                   tropical                              1 standard
# 28                       arid                           0.62 standard
# 6                   temperate                           0.85 standard
# 15                     frigid                              1 standard
# 33                  temperate                                       1
# 17           temperate, moist                              1 standard
# 16                 hot, humid                           0.75 standard
# 5                   temperate  1.5 (surface), 1 standard (Cloud City)
# 14      artificial temperate                            0.56 standard
# 41                  temperate                                    0.98
# 0                        arid                              1 standard
# 12                        hot                              1 standard
# 35                  temperate                                     0.9
# 2         temperate, tropical                              1 standard
# 24                  temperate                              1 standard
# 40                        NaN                                     NaN
#
#                                      terrain  surface_water    population  \
# 8                       cityscape, mountains           38.2  1.000000e+12
# 55                              urban, vines           38.2  5.000000e+11
# 10            rock, desert, mountain, barren            5.0  1.000000e+11
# 50                                   deserts           38.2  3.980003e+10
# 37                                       NaN           38.2  3.980003e+10
# 39    desert, tundra, rainforests, mountains           38.2  3.980003e+10
# 44                 rocky canyons, acid pools           38.2  3.980003e+10
# 45                                       NaN           38.2  3.980003e+10
# 46                                     rocky           38.2  3.980003e+10
# 47                                       NaN           38.2  3.980003e+10
# 48                                       NaN           38.2  3.980003e+10
# 59                                       NaN           38.2  3.980003e+10
# 27                                       NaN           38.2  3.980003e+10
# 51            rainforests, rivers, mountains           38.2  3.980003e+10
# 52                 jungles, forests, deserts           38.2  3.980003e+10
# 53                                       NaN           38.2  3.980003e+10
# 4                             swamp, jungles            8.0  3.980003e+10
# 3         tundra, ice caves, mountain ranges          100.0  3.980003e+10
# 57           cities, savannahs, seas, plains           38.2  3.980003e+10
# 19                                     grass           38.2  3.980003e+10
# 30                    oceans, reefs, islands          100.0  2.700000e+10
# 20                                 cityscape           38.2  2.200000e+10
# 32       mountains, volcanoes, rocky deserts            5.0  1.850000e+10
# 23               urban, oceans, swamps, bogs           38.2  7.000000e+09
# 56         plains, forests, hills, mountains           25.0  5.000000e+09
# 7   grassy hills, swamps, forests, mountains           12.0  4.500000e+09
# 58        rainforests, cliffs, canyons, seas           38.2  4.000000e+09
# 26                       plains, seas, mesas           10.0  4.000000e+09
# 49             oceans, rainforests, plateaus           38.2  3.500000e+09
# 21             plains, urban, hills, forests           70.0  3.000000e+09
# 34       swamps, deserts, jungles, mountains           38.2  2.000000e+09
# 1                      grasslands, mountains           40.0  2.000000e+09
# 36       mountains, valleys, deserts, tundra            5.0  1.500000e+09
# 18       caves, desert, mountains, volcanoes           38.2  1.400000e+09
# 22            jungles, oceans, urban, swamps           60.0  1.300000e+09
# 31                           plains, forests           40.0  1.200000e+09
# 9                                      ocean          100.0  1.000000e+09
# 54                          oceans, glaciers          100.0  5.000000e+08
# 43              lakes, islands, swamps, seas           80.0  5.000000e+08
# 42                                   verdant           20.0  4.500000e+08
# 38                             urban, barren           38.2  4.210000e+08
# 29                        deserts, mountains           38.2  3.000000e+08
# 11   scrublands, savanna, canyons, sinkholes           38.2  9.500000e+07
# 25                     rocky islands, oceans           98.0  6.200000e+07
# 13            jungle, forests, lakes, rivers           60.0  4.500000e+07
# 28      mountains, seas, grasslands, deserts           38.2  4.200000e+07
# 6                  forests, mountains, lakes            8.0  3.000000e+07
# 15          glaciers, mountains, ice canyons           38.2  1.900000e+07
# 33                             swamps, lakes           38.2  1.100000e+07
# 17   mountains, fields, forests, rock arches           38.2  1.000000e+07
# 16                            fungus forests           38.2  8.500000e+06
# 5                                  gas giant            0.0  6.000000e+06
# 14                          airless asteroid            0.0  1.000000e+06
# 41       toxic cloudsea, plateaus, volcanoes           38.2  7.053000e+05
# 0                                     desert            1.0  2.000000e+05
# 12  volcanoes, lava rivers, mountains, caves            0.0  2.000000e+04
# 35                forests, deserts, savannas           38.2  5.200000e+03
# 2                        jungle, rainforests            8.0  1.000000e+03
# 24   oceans, savannas, mountains, grasslands           38.2  1.000000e+03
# 40                               barren, ash           38.2  0.000000e+00
#
#                                             residents  \
# 8   [https://swapi.dev/api/people/34/, https://swa...
# 55                 [https://swapi.dev/api/people/76/]
# 10                 [https://swapi.dev/api/people/63/]
# 50  [https://swapi.dev/api/people/64/, https://swa...
# 37                 [https://swapi.dev/api/people/47/]
# 39                 [https://swapi.dev/api/people/49/]
# 44                 [https://swapi.dev/api/people/54/]
# 45                                                 []
# 46                 [https://swapi.dev/api/people/56/]
# 47                 [https://swapi.dev/api/people/57/]
# 48                 [https://swapi.dev/api/people/58/]
# 59                 [https://swapi.dev/api/people/82/]
# 27  [https://swapi.dev/api/people/20/, https://swa...
# 51                 [https://swapi.dev/api/people/67/]
# 52                 [https://swapi.dev/api/people/69/]
# 53                 [https://swapi.dev/api/people/70/]
# 4                                                  []
# 3                                                  []
# 57                 [https://swapi.dev/api/people/78/]
# 19                 [https://swapi.dev/api/people/10/]
# 30                 [https://swapi.dev/api/people/27/]
# 20                 [https://swapi.dev/api/people/12/]
# 32                 [https://swapi.dev/api/people/31/]
# 23                 [https://swapi.dev/api/people/16/]
# 56                 [https://swapi.dev/api/people/77/]
# 7   [https://swapi.dev/api/people/3/, https://swap...
# 58                 [https://swapi.dev/api/people/79/]
# 26                                                 []
# 49                 [https://swapi.dev/api/people/59/]
# 21  [https://swapi.dev/api/people/14/, https://swa...
# 34                 [https://swapi.dev/api/people/41/]
# 1   [https://swapi.dev/api/people/5/, https://swap...
# 36  [https://swapi.dev/api/people/45/, https://swa...
# 18                                                 []
# 22                 [https://swapi.dev/api/people/15/]
# 31                 [https://swapi.dev/api/people/28/]
# 9   [https://swapi.dev/api/people/22/, https://swa...
# 54                 [https://swapi.dev/api/people/71/]
# 43                 [https://swapi.dev/api/people/53/]
# 42                 [https://swapi.dev/api/people/52/]
# 38                 [https://swapi.dev/api/people/48/]
# 29                 [https://swapi.dev/api/people/25/]
# 11                 [https://swapi.dev/api/people/83/]
# 25                 [https://swapi.dev/api/people/19/]
# 13  [https://swapi.dev/api/people/13/, https://swa...
# 28                 [https://swapi.dev/api/people/24/]
# 6                  [https://swapi.dev/api/people/30/]
# 15                                                 []
# 33                 [https://swapi.dev/api/people/40/]
# 17                 [https://swapi.dev/api/people/33/]
# 16                                                 []
# 5                  [https://swapi.dev/api/people/26/]
# 14                                                 []
# 41                 [https://swapi.dev/api/people/51/]
# 0   [https://swapi.dev/api/people/1/, https://swap...
# 12                                                 []
# 35                 [https://swapi.dev/api/people/44/]
# 2                                                  []
# 24                                                 []
# 40                 [https://swapi.dev/api/people/50/]
#
#                                                 films  \
# 8   [https://swapi.dev/api/films/3/, https://swapi...
# 55                                                 []
# 10                   [https://swapi.dev/api/films/5/]
# 50                                                 []
# 37                                                 []
# 39                                                 []
# 44                                                 []
# 45                                                 []
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 59                                                 []
# 27                                                 []
# 51                                                 []
# 52                                                 []
# 53                                                 []
# 4   [https://swapi.dev/api/films/2/, https://swapi...
# 3                    [https://swapi.dev/api/films/2/]
# 57                                                 []
# 19                                                 []
# 30                                                 []
# 20                                                 []
# 32                                                 []
# 23                                                 []
# 56                                                 []
# 7   [https://swapi.dev/api/films/3/, https://swapi...
# 58                                                 []
# 26                   [https://swapi.dev/api/films/2/]
# 49                                                 []
# 21                                                 []
# 34                                                 []
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 36                                                 []
# 18                   [https://swapi.dev/api/films/6/]
# 22                                                 []
# 31                                                 []
# 9                    [https://swapi.dev/api/films/5/]
# 54                                                 []
# 43                                                 []
# 42                                                 []
# 38                                                 []
# 29                                                 []
# 11                   [https://swapi.dev/api/films/6/]
# 25                                                 []
# 13                   [https://swapi.dev/api/films/6/]
# 28                                                 []
# 6                    [https://swapi.dev/api/films/3/]
# 15                   [https://swapi.dev/api/films/6/]
# 33                                                 []
# 17                   [https://swapi.dev/api/films/6/]
# 16                   [https://swapi.dev/api/films/6/]
# 5                    [https://swapi.dev/api/films/2/]
# 14                   [https://swapi.dev/api/films/6/]
# 41                                                 []
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 12                   [https://swapi.dev/api/films/6/]
# 35                                                 []
# 2                    [https://swapi.dev/api/films/1/]
# 24                                                 []
# 40                                                 []
#
#                         created                       edited  \
# 8   2014-12-10T11:54:13.921000Z  2014-12-20T20:58:18.432000Z
# 55  2014-12-20T17:50:47.864000Z  2014-12-20T20:58:18.517000Z
# 10  2014-12-10T12:47:22.350000Z  2014-12-20T20:58:18.437000Z
# 50  2014-12-20T16:44:46.318000Z  2014-12-20T20:58:18.508000Z
# 37  2014-12-20T09:52:23.452000Z  2014-12-20T20:58:18.483000Z
# 39  2014-12-20T10:01:37.395000Z  2014-12-20T20:58:18.487000Z
# 44  2014-12-20T10:26:05.788000Z  2014-12-20T20:58:18.497000Z
# 45  2014-12-20T10:28:31.117000Z  2014-12-20T20:58:18.498000Z
# 46  2014-12-20T10:31:32.413000Z  2014-12-20T20:58:18.500000Z
# 47  2014-12-20T10:34:08.249000Z  2014-12-20T20:58:18.502000Z
# 48  2014-12-20T10:48:36.141000Z  2014-12-20T20:58:18.504000Z
# 59  2014-12-20T20:18:36.256000Z  2014-12-20T20:58:18.525000Z
# 27  2014-12-15T12:25:59.569000Z  2014-12-20T20:58:18.466000Z
# 51  2014-12-20T16:52:13.357000Z  2014-12-20T20:58:18.510000Z
# 52  2014-12-20T16:54:39.909000Z  2014-12-20T20:58:18.512000Z
# 53  2014-12-20T16:56:37.250000Z  2014-12-20T20:58:18.514000Z
# 4   2014-12-10T11:42:22.590000Z  2014-12-20T20:58:18.425000Z
# 3   2014-12-10T11:39:13.934000Z  2014-12-20T20:58:18.423000Z
# 57  2014-12-20T18:43:14.049000Z  2014-12-20T20:58:18.521000Z
# 19  2014-12-10T16:16:26.566000Z  2014-12-20T20:58:18.452000Z
# 30  2014-12-18T11:07:01.792000Z  2014-12-20T20:58:18.471000Z
# 20  2014-12-10T16:26:54.384000Z  2014-12-20T20:58:18.454000Z
# 32  2014-12-18T11:25:40.243000Z  2014-12-20T20:58:18.474000Z
# 23  2014-12-10T17:11:29.452000Z  2014-12-20T20:58:18.460000Z
# 56  2014-12-20T17:57:47.420000Z  2014-12-20T20:58:18.519000Z
# 7   2014-12-10T11:52:31.066000Z  2014-12-20T20:58:18.430000Z
# 58  2014-12-20T19:43:51.278000Z  2014-12-20T20:58:18.523000Z
# 26  2014-12-15T12:23:41.661000Z  2014-12-20T20:58:18.464000Z
# 49  2014-12-20T10:52:51.524000Z  2014-12-20T20:58:18.506000Z
# 21  2014-12-10T16:49:12.453000Z  2014-12-20T20:58:18.456000Z
# 34  2014-12-19T17:52:13.106000Z  2014-12-20T20:58:18.478000Z
# 1   2014-12-10T11:35:48.479000Z  2014-12-20T20:58:18.420000Z
# 36  2014-12-20T09:46:25.740000Z  2014-12-20T20:58:18.481000Z
# 18  2014-12-10T13:47:46.874000Z  2014-12-20T20:58:18.450000Z
# 22  2014-12-10T17:03:28.110000Z  2014-12-20T20:58:18.458000Z
# 31  2014-12-18T11:11:51.872000Z  2014-12-20T20:58:18.472000Z
# 9   2014-12-10T12:45:06.577000Z  2014-12-20T20:58:18.434000Z
# 54  2014-12-20T17:27:41.286000Z  2014-12-20T20:58:18.516000Z
# 43  2014-12-20T10:18:26.110000Z  2014-12-20T20:58:18.495000Z
# 42  2014-12-20T10:14:48.178000Z  2014-12-20T20:58:18.493000Z
# 38  2014-12-20T09:56:58.874000Z  2014-12-20T20:58:18.485000Z
# 29  2014-12-15T12:56:31.121000Z  2014-12-20T20:58:18.469000Z
# 11  2014-12-10T12:49:01.491000Z  2014-12-20T20:58:18.439000Z
# 25  2014-12-12T11:16:55.078000Z  2014-12-20T20:58:18.463000Z
# 13  2014-12-10T13:32:00.124000Z  2014-12-20T20:58:18.442000Z
# 28  2014-12-15T12:53:47.695000Z  2014-12-20T20:58:18.468000Z
# 6   2014-12-10T11:50:29.349000Z  2014-12-20T20:58:18.429000Z
# 15  2014-12-10T13:43:39.139000Z  2014-12-20T20:58:18.446000Z
# 33  2014-12-19T17:47:54.403000Z  2014-12-20T20:58:18.476000Z
# 17  2014-12-10T13:46:28.704000Z  2014-12-20T20:58:18.449000Z
# 16  2014-12-10T13:44:50.397000Z  2014-12-20T20:58:18.447000Z
# 5   2014-12-10T11:43:55.240000Z  2014-12-20T20:58:18.427000Z
# 14  2014-12-10T13:33:46.405000Z  2014-12-20T20:58:18.444000Z
# 41  2014-12-20T10:12:28.980000Z  2014-12-20T20:58:18.491000Z
# 0   2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 12  2014-12-10T12:50:16.526000Z  2014-12-20T20:58:18.440000Z
# 35  2014-12-19T18:00:40.142000Z  2014-12-20T20:58:18.480000Z
# 2   2014-12-10T11:37:19.144000Z  2014-12-20T20:58:18.421000Z
# 24  2014-12-10T17:23:29.896000Z  2014-12-20T20:58:18.461000Z
# 40  2014-12-20T10:07:29.578000Z  2014-12-20T20:58:18.489000Z
#
#                                   url
# 8    https://swapi.dev/api/planets/9/
# 55  https://swapi.dev/api/planets/56/
# 10  https://swapi.dev/api/planets/11/
# 50  https://swapi.dev/api/planets/51/
# 37  https://swapi.dev/api/planets/38/
# 39  https://swapi.dev/api/planets/40/
# 44  https://swapi.dev/api/planets/45/
# 45  https://swapi.dev/api/planets/46/
# 46  https://swapi.dev/api/planets/47/
# 47  https://swapi.dev/api/planets/48/
# 48  https://swapi.dev/api/planets/49/
# 59  https://swapi.dev/api/planets/60/
# 27  https://swapi.dev/api/planets/28/
# 51  https://swapi.dev/api/planets/52/
# 52  https://swapi.dev/api/planets/53/
# 53  https://swapi.dev/api/planets/54/
# 4    https://swapi.dev/api/planets/5/
# 3    https://swapi.dev/api/planets/4/
# 57  https://swapi.dev/api/planets/58/
# 19  https://swapi.dev/api/planets/20/
# 30  https://swapi.dev/api/planets/31/
# 20  https://swapi.dev/api/planets/21/
# 32  https://swapi.dev/api/planets/33/
# 23  https://swapi.dev/api/planets/24/
# 56  https://swapi.dev/api/planets/57/
# 7    https://swapi.dev/api/planets/8/
# 58  https://swapi.dev/api/planets/59/
# 26  https://swapi.dev/api/planets/27/
# 49  https://swapi.dev/api/planets/50/
# 21  https://swapi.dev/api/planets/22/
# 34  https://swapi.dev/api/planets/35/
# 1    https://swapi.dev/api/planets/2/
# 36  https://swapi.dev/api/planets/37/
# 18  https://swapi.dev/api/planets/19/
# 22  https://swapi.dev/api/planets/23/
# 31  https://swapi.dev/api/planets/32/
# 9   https://swapi.dev/api/planets/10/
# 54  https://swapi.dev/api/planets/55/
# 43  https://swapi.dev/api/planets/44/
# 42  https://swapi.dev/api/planets/43/
# 38  https://swapi.dev/api/planets/39/
# 29  https://swapi.dev/api/planets/30/
# 11  https://swapi.dev/api/planets/12/
# 25  https://swapi.dev/api/planets/26/
# 13  https://swapi.dev/api/planets/14/
# 28  https://swapi.dev/api/planets/29/
# 6    https://swapi.dev/api/planets/7/
# 15  https://swapi.dev/api/planets/16/
# 33  https://swapi.dev/api/planets/34/
# 17  https://swapi.dev/api/planets/18/
# 16  https://swapi.dev/api/planets/17/
# 5    https://swapi.dev/api/planets/6/
# 14  https://swapi.dev/api/planets/15/
# 41  https://swapi.dev/api/planets/42/
# 0    https://swapi.dev/api/planets/1/
# 12  https://swapi.dev/api/planets/13/
# 35  https://swapi.dev/api/planets/36/
# 2    https://swapi.dev/api/planets/3/
# 24  https://swapi.dev/api/planets/25/
# 40  https://swapi.dev/api/planets/41/

# %%
#fined all climate kinds
planets['climate'].unique()
# Out:
# array(['arid', 'temperate', 'temperate, tropical', 'frozen', 'murky',
#        'temperate, arid', 'temperate, arid, windy', 'hot', 'tropical',
#        'artificial temperate ', 'frigid', 'hot, humid',
#        'temperate, moist', 'polluted', 'unknown', 'superheated',
#        'arid, temperate, tropical', 'temperate, arid, subartic',
#        'temperate, artic', 'tropical, temperate', 'arid, rocky, windy'],
#       dtype=object)

# %%
#change the type og those colummns to easy calculate
planets = df_columns_to_numeric(planets,["rotation_period",'orbital_period','diameter','surface_water','population'])

planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             60 non-null     object
#  1   rotation_period  48 non-null     float64
#  2   orbital_period   48 non-null     float64
#  3   diameter         44 non-null     float64
#  4   climate          60 non-null     object
#  5   gravity          60 non-null     object
#  6   terrain          60 non-null     object
#  7   surface_water    25 non-null     float64
#  8   population       43 non-null     float64
#  9   residents        60 non-null     object
#  10  films            60 non-null     object
#  11  created          60 non-null     object
#  12  edited           60 non-null     object
#  13  url              60 non-null     object
# dtypes: float64(5), object(9)
# memory usage: 6.7+ KB

# %%
missing_values=['??','Na','X','999999','unknown']
planets=planets.replace(missing_values,np.NaN)

# %%
planets.describe()
# Out:
#        rotation_period  orbital_period       diameter  surface_water  \
# count        48.000000       48.000000      44.000000      25.000000
# mean         25.958333      577.625000   12388.340909      38.200000
# std          11.185017      953.304904   17045.948720      38.923001
# min           0.000000        0.000000       0.000000       0.000000
# 25%          22.750000      310.250000    7812.250000       5.000000
# 50%          25.000000      374.500000   11015.000000      20.000000
# 75%          27.000000      412.000000   13422.500000      70.000000
# max          87.000000     5110.000000  118000.000000     100.000000
#
#          population
# count  4.300000e+01
# mean   3.980003e+10
# std    1.685799e+11
# min    0.000000e+00
# 25%    1.050000e+07
# 50%    5.000000e+08
# 75%    3.750000e+09
# max    1.000000e+12

# %%
planets.isnull().sum()
# Out:
# name                1
# rotation_period    12
# orbital_period     12
# diameter           16
# climate            12
# gravity            15
# terrain             7
# surface_water      35
# population         17
# residents           0
# films               0
# created             0
# edited              0
# url                 0
# dtype: int64

# %%
#fill the empty values of these columns by the mean
planets["rotation_period"].fillna(planets["rotation_period"].mean(),inplace=True)
planets["orbital_period"].fillna(planets["orbital_period"].mean(),inplace=True)
planets["diameter"].fillna(planets["diameter"].mean(),inplace=True)
planets["surface_water"].fillna(planets["surface_water"].mean(),inplace=True)
planets["population"].fillna(planets["population"].mean(),inplace=True)

# %%
planets.isnull().sum()
# Out:
# name                1
# rotation_period     0
# orbital_period      0
# diameter            0
# climate            12
# gravity            15
# terrain             7
# surface_water       0
# population          0
# residents           0
# films               0
# created             0
# edited              0
# url                 0
# dtype: int64

# %%
#relationship between populationand diameterS
sns.relplot( x=planets["diameter"], y=planets["population"])

# %% [markdown]
# Films

# %%
films= get_full_type_data('http://swapi.dev/api/films/')
print("Number of films",films.shape[0])
# Out:
# Number of films 6

# %%
films.head()
# Out:
#                      title  episode_id  \
# 0               A New Hope           4
# 1  The Empire Strikes Back           5
# 2       Return of the Jedi           6
# 3       The Phantom Menace           1
# 4     Attack of the Clones           2
#
#                                        opening_crawl          director  \
# 0  It is a period of civil war.\r\nRebel spaceshi...      George Lucas
# 1  It is a dark time for the\r\nRebellion. Althou...    Irvin Kershner
# 2  Luke Skywalker has returned to\r\nhis home pla...  Richard Marquand
# 3  Turmoil has engulfed the\r\nGalactic Republic....      George Lucas
# 4  There is unrest in the Galactic\r\nSenate. Sev...      George Lucas
#
#                                            producer release_date  \
# 0                         Gary Kurtz, Rick McCallum   1977-05-25
# 1                         Gary Kurtz, Rick McCallum   1980-05-17
# 2  Howard G. Kazanjian, George Lucas, Rick McCallum   1983-05-25
# 3                                     Rick McCallum   1999-05-19
# 4                                     Rick McCallum   2002-05-16
#
#                                           characters  \
# 0  [https://swapi.dev/api/people/1/, https://swap...
# 1  [https://swapi.dev/api/people/1/, https://swap...
# 2  [https://swapi.dev/api/people/1/, https://swap...
# 3  [https://swapi.dev/api/people/2/, https://swap...
# 4  [https://swapi.dev/api/people/2/, https://swap...
#
#                                              planets  \
# 0  [https://swapi.dev/api/planets/1/, https://swa...
# 1  [https://swapi.dev/api/planets/4/, https://swa...
# 2  [https://swapi.dev/api/planets/1/, https://swa...
# 3  [https://swapi.dev/api/planets/1/, https://swa...
# 4  [https://swapi.dev/api/planets/1/, https://swa...
#
#                                            starships  \
# 0  [https://swapi.dev/api/starships/2/, https://s...
# 1  [https://swapi.dev/api/starships/3/, https://s...
# 2  [https://swapi.dev/api/starships/2/, https://s...
# 3  [https://swapi.dev/api/starships/31/, https://...
# 4  [https://swapi.dev/api/starships/21/, https://...
#
#                                             vehicles  \
# 0  [https://swapi.dev/api/vehicles/4/, https://sw...
# 1  [https://swapi.dev/api/vehicles/8/, https://sw...
# 2  [https://swapi.dev/api/vehicles/8/, https://sw...
# 3  [https://swapi.dev/api/vehicles/33/, https://s...
# 4  [https://swapi.dev/api/vehicles/4/, https://sw...
#
#                                              species  \
# 0  [https://swapi.dev/api/species/1/, https://swa...
# 1  [https://swapi.dev/api/species/1/, https://swa...
# 2  [https://swapi.dev/api/species/1/, https://swa...
# 3  [https://swapi.dev/api/species/1/, https://swa...
# 4  [https://swapi.dev/api/species/1/, https://swa...
#
#                        created                       edited  \
# 0  2014-12-10T14:23:31.880000Z  2014-12-20T19:49:45.256000Z
# 1  2014-12-12T11:26:24.656000Z  2014-12-15T13:07:53.386000Z
# 2  2014-12-18T10:39:33.255000Z  2014-12-20T09:48:37.462000Z
# 3  2014-12-19T16:52:55.740000Z  2014-12-20T10:54:07.216000Z
# 4  2014-12-20T10:57:57.886000Z  2014-12-20T20:18:48.516000Z
#
#                               url
# 0  https://swapi.dev/api/films/1/
# 1  https://swapi.dev/api/films/2/
# 2  https://swapi.dev/api/films/3/
# 3  https://swapi.dev/api/films/4/
# 4  https://swapi.dev/api/films/5/

# %%
films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          6 non-null      object
#  1   episode_id     6 non-null      int64
#  2   opening_crawl  6 non-null      object
#  3   director       6 non-null      object
#  4   producer       6 non-null      object
#  5   release_date   6 non-null      object
#  6   characters     6 non-null      object
#  7   planets        6 non-null      object
#  8   starships      6 non-null      object
#  9   vehicles       6 non-null      object
#  10  species        6 non-null      object
#  11  created        6 non-null      object
#  12  edited         6 non-null      object
#  13  url            6 non-null      object
# dtypes: int64(1), object(13)
# memory usage: 800.0+ bytes

# %%
films.columns
# Out:
# Index(['title', 'episode_id', 'opening_crawl', 'director', 'producer',
#        'release_date', 'characters', 'planets', 'starships', 'vehicles',
#        'species', 'created', 'edited', 'url'],
#       dtype='object')

# %%
films.describe()
# Out:
#        episode_id
# count    6.000000
# mean     3.500000
# std      1.870829
# min      1.000000
# 25%      2.250000
# 50%      3.500000
# 75%      4.750000
# max      6.000000

# %%
films.isnull().sum()
# Out:
# title            0
# episode_id       0
# opening_crawl    0
# director         0
# producer         0
# release_date     0
# characters       0
# planets          0
# starships        0
# vehicles         0
# species          0
# created          0
# edited           0
# url              0
# dtype: int64

# %%
missing_values=['??','na','X','999999']
films=films.replace(missing_values,np.NaN)

# %% [markdown]
# Speicies

# %%
species = get_full_type_data('http://swapi.dev/api/species/')
print("Number of films",species.shape[0])
# Out:
# Number of films 37

# %%
species.columns
# Out:
# Index(['name', 'classification', 'designation', 'average_height',
#        'skin_colors', 'hair_colors', 'eye_colors', 'average_lifespan',
#        'homeworld', 'language', 'people', 'films', 'created', 'edited', 'url'],
#       dtype='object')

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              37 non-null     object
#  1   classification    37 non-null     object
#  2   designation       37 non-null     object
#  3   average_height    37 non-null     object
#  4   skin_colors       37 non-null     object
#  5   hair_colors       37 non-null     object
#  6   eye_colors        37 non-null     object
#  7   average_lifespan  37 non-null     object
#  8   homeworld         36 non-null     object
#  9   language          37 non-null     object
#  10  people            37 non-null     object
#  11  films             37 non-null     object
#  12  created           37 non-null     object
#  13  edited            37 non-null     object
#  14  url               37 non-null     object
# dtypes: object(15)
# memory usage: 4.5+ KB

# %%
# Collect unnecessary columns
column_to_drop = ['people','films','created','edited', 'url']
# Drop unnecessary columns
species.drop(column_to_drop, inplace=True, axis=1)

# %%
species.head()
# Out:
#      name classification designation average_height  \
# 0   Human         mammal    sentient            180
# 1   Droid     artificial    sentient            n/a
# 2  Wookie         mammal    sentient            210
# 3  Rodian       sentient   reptilian            170
# 4    Hutt      gastropod    sentient            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                n/a                        n/a
# 2                               gray               black, brown
# 3                        green, blue                        n/a
# 4                  green, brown, tan                        n/a
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                      n/a       indefinite
# 2  blue, green, yellow, brown, golden, red              400
# 3                                    black          unknown
# 4                              yellow, red             1000
#
#                            homeworld        language
# 0   https://swapi.dev/api/planets/9/  Galactic Basic
# 1                               None             n/a
# 2  https://swapi.dev/api/planets/14/      Shyriiwook
# 3  https://swapi.dev/api/planets/23/   Galatic Basic
# 4  https://swapi.dev/api/planets/24/         Huttese

# %%
#replace missing values on none
missing_values = ['??','X','999999', 'unknown', 'indefinite', 'n/a']
for val in missing_values:
    species = species.replace(val, None)

# %%
species.head()
# Out:
#      name classification designation average_height  \
# 0   Human         mammal    sentient            180
# 1   Droid     artificial    sentient           None
# 2  Wookie         mammal    sentient            210
# 3  Rodian       sentient   reptilian            170
# 4    Hutt      gastropod    sentient            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                               None                       None
# 2                               gray               black, brown
# 3                        green, blue                       None
# 4                  green, brown, tan                       None
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                     None             None
# 2  blue, green, yellow, brown, golden, red              400
# 3                                    black             None
# 4                              yellow, red             1000
#
#                            homeworld        language
# 0   https://swapi.dev/api/planets/9/  Galactic Basic
# 1                               None            None
# 2  https://swapi.dev/api/planets/14/      Shyriiwook
# 3  https://swapi.dev/api/planets/23/   Galatic Basic
# 4  https://swapi.dev/api/planets/24/         Huttese

# %%
column = 'designation'
species[column].value_counts()
# Out:
# sentient     36
# reptilian     1
# Name: designation, dtype: int64

# %%
# df = pd.DataFrame(technologies)
group = {"sentient":"group_1", "reptilian":"group_2"}
species_data = species['designation'].map(group)

species.insert(3, 'designation_group', species_data)
species.head()
# Out:
#      name classification designation designation_group average_height  \
# 0   Human         mammal    sentient           group_1            180
# 1   Droid     artificial    sentient           group_1           None
# 2  Wookie         mammal    sentient           group_1            210
# 3  Rodian       sentient   reptilian           group_2            170
# 4    Hutt      gastropod    sentient           group_1            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                               None                       None
# 2                               gray               black, brown
# 3                        green, blue                       None
# 4                  green, brown, tan                       None
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                     None             None
# 2  blue, green, yellow, brown, golden, red              400
# 3                                    black             None
# 4                              yellow, red             1000
#
#                            homeworld        language
# 0   https://swapi.dev/api/planets/9/  Galactic Basic
# 1                               None            None
# 2  https://swapi.dev/api/planets/14/      Shyriiwook
# 3  https://swapi.dev/api/planets/23/   Galatic Basic
# 4  https://swapi.dev/api/planets/24/         Huttese

# %%
species['skin_colors_num'] = species['skin_colors'].apply(lambda x: len(x.split(',')))
species['hair_colors_num'] = species['hair_colors'].apply(lambda x: len(x.split(',')))

# %%
species.head()
# Out:
#               name classification designation average_height  \
# 0            Human         mammal    sentient            180
# 1            Droid     artificial    sentient            n/a
# 2           Wookie         mammal    sentient            210
# 3           Rodian       sentient   reptilian            170
# 4             Hutt      gastropod    sentient            300
# 5   Yoda's species         mammal    sentient             66
# 6       Trandoshan        reptile    sentient            200
# 7     Mon Calamari      amphibian    sentient            160
# 8             Ewok         mammal    sentient            100
# 9        Sullustan         mammal    sentient            180
# 10       Neimodian        unknown    sentient            180
# 11          Gungan      amphibian    sentient            190
# 12       Toydarian         mammal    sentient            120
# 13             Dug         mammal    sentient            100
# 14         Twi'lek        mammals    sentient            200
# 15          Aleena        reptile    sentient             80
# 16      Vulptereen        unknown    sentient            100
# 17           Xexto        unknown    sentient            125
# 18           Toong        unknown    sentient            200
# 19          Cerean         mammal    sentient            200
# 20        Nautolan      amphibian    sentient            180
# 21          Zabrak         mammal    sentient            180
# 22      Tholothian         mammal    sentient        unknown
# 23        Iktotchi        unknown    sentient            180
# 24        Quermian         mammal    sentient            240
# 25         Kel Dor        unknown    sentient            180
# 26        Chagrian      amphibian    sentient            190
# 27       Geonosian      insectoid    sentient            178
# 28        Mirialan         mammal    sentient            180
# 29        Clawdite      reptilian    sentient            180
# 30        Besalisk      amphibian    sentient            178
# 31        Kaminoan      amphibian    sentient            220
# 32         Skakoan         mammal    sentient        unknown
# 33            Muun         mammal    sentient            190
# 34         Togruta         mammal    sentient            180
# 35         Kaleesh        reptile    sentient            170
# 36          Pau'an         mammal    sentient            190
#
#                                        skin_colors                hair_colors  \
# 0                caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                              n/a                        n/a
# 2                                             gray               black, brown
# 3                                      green, blue                        n/a
# 4                                green, brown, tan                        n/a
# 5                                    green, yellow               brown, white
# 6                                     brown, green                       none
# 7                        red, blue, brown, magenta                       none
# 8                                            brown        white, brown, black
# 9                                             pale                       none
# 10                                     grey, green                       none
# 11                                    brown, green                       none
# 12                               blue, green, grey                       none
# 13                        brown, purple, grey, red                       none
# 14  orange, yellow, blue, green, pink, purple, tan                       none
# 15                                      blue, gray                       none
# 16                                            grey                       none
# 17                            grey, yellow, purple                       none
# 18                             grey, green, yellow                       none
# 19                                       pale pink   red, blond, black, white
# 20                         green, blue, brown, red                       none
# 21                pale, brown, red, orange, yellow                      black
# 22                                            dark                    unknown
# 23                                            pink                       none
# 24                                           white                       none
# 25                              peach, orange, red                       none
# 26                                            blue                       none
# 27                                    green, brown                       none
# 28                                   yellow, green               black, brown
# 29                                   green, yellow                       none
# 30                                           brown                       none
# 31                                      grey, blue                       none
# 32                                     grey, green                       none
# 33                                     grey, white                       none
# 34         red, white, orange, yellow, green, blue                       none
# 35                              brown, orange, tan                       none
# 36                                            grey                       none
#
#                                  eye_colors average_lifespan  \
# 0    brown, blue, green, hazel, grey, amber              120
# 1                                       n/a       indefinite
# 2   blue, green, yellow, brown, golden, red              400
# 3                                     black          unknown
# 4                               yellow, red             1000
# 5                      brown, green, yellow              900
# 6                            yellow, orange          unknown
# 7                                    yellow          unknown
# 8                             orange, brown          unknown
# 9                                     black          unknown
# 10                                red, pink          unknown
# 11                                   orange          unknown
# 12                                   yellow               91
# 13                             yellow, blue          unknown
# 14                blue, brown, orange, pink          unknown
# 15                                  unknown               79
# 16                                   yellow          unknown
# 17                                    black          unknown
# 18                                   orange          unknown
# 19                                    hazel          unknown
# 20                                    black               70
# 21                            brown, orange          unknown
# 22                             blue, indigo          unknown
# 23                                   orange          unknown
# 24                                   yellow               86
# 25                            black, silver               70
# 26                                     blue          unknown
# 27                             green, hazel          unknown
# 28  blue, green, red, yellow, brown, orange          unknown
# 29                                   yellow               70
# 30                                   yellow               75
# 31                                    black               80
# 32                                  unknown          unknown
# 33                                    black              100
# 34  red, orange, yellow, green, blue, black               94
# 35                                   yellow               80
# 36                                    black              700
#
#                             homeworld        language  \
# 0    https://swapi.dev/api/planets/9/  Galactic Basic
# 1                                None             n/a
# 2   https://swapi.dev/api/planets/14/      Shyriiwook
# 3   https://swapi.dev/api/planets/23/   Galatic Basic
# 4   https://swapi.dev/api/planets/24/         Huttese
# 5   https://swapi.dev/api/planets/28/  Galactic basic
# 6   https://swapi.dev/api/planets/29/            Dosh
# 7   https://swapi.dev/api/planets/31/  Mon Calamarian
# 8    https://swapi.dev/api/planets/7/         Ewokese
# 9   https://swapi.dev/api/planets/33/       Sullutese
# 10  https://swapi.dev/api/planets/18/       Neimoidia
# 11   https://swapi.dev/api/planets/8/    Gungan basic
# 12  https://swapi.dev/api/planets/34/       Toydarian
# 13  https://swapi.dev/api/planets/35/          Dugese
# 14  https://swapi.dev/api/planets/37/        Twi'leki
# 15  https://swapi.dev/api/planets/38/          Aleena
# 16  https://swapi.dev/api/planets/39/      vulpterish
# 17  https://swapi.dev/api/planets/40/         Xextese
# 18  https://swapi.dev/api/planets/41/          Tundan
# 19  https://swapi.dev/api/planets/43/          Cerean
# 20  https://swapi.dev/api/planets/44/         Nautila
# 21  https://swapi.dev/api/planets/45/         Zabraki
# 22  https://swapi.dev/api/planets/46/         unknown
# 23  https://swapi.dev/api/planets/47/      Iktotchese
# 24  https://swapi.dev/api/planets/48/        Quermian
# 25  https://swapi.dev/api/planets/49/         Kel Dor
# 26  https://swapi.dev/api/planets/50/         Chagria
# 27  https://swapi.dev/api/planets/11/       Geonosian
# 28  https://swapi.dev/api/planets/51/        Mirialan
# 29  https://swapi.dev/api/planets/54/        Clawdite
# 30  https://swapi.dev/api/planets/55/        besalisk
# 31  https://swapi.dev/api/planets/10/        Kaminoan
# 32  https://swapi.dev/api/planets/56/         Skakoan
# 33  https://swapi.dev/api/planets/57/            Muun
# 34  https://swapi.dev/api/planets/58/         Togruti
# 35  https://swapi.dev/api/planets/59/         Kaleesh
# 36  https://swapi.dev/api/planets/12/         Utapese
#
#                                                people  \
# 0   [https://swapi.dev/api/people/66/, https://swa...
# 1   [https://swapi.dev/api/people/2/, https://swap...
# 2   [https://swapi.dev/api/people/13/, https://swa...
# 3                  [https://swapi.dev/api/people/15/]
# 4                  [https://swapi.dev/api/people/16/]
# 5                  [https://swapi.dev/api/people/20/]
# 6                  [https://swapi.dev/api/people/24/]
# 7                  [https://swapi.dev/api/people/27/]
# 8                  [https://swapi.dev/api/people/30/]
# 9                  [https://swapi.dev/api/people/31/]
# 10                 [https://swapi.dev/api/people/33/]
# 11  [https://swapi.dev/api/people/36/, https://swa...
# 12                 [https://swapi.dev/api/people/40/]
# 13                 [https://swapi.dev/api/people/41/]
# 14  [https://swapi.dev/api/people/45/, https://swa...
# 15                 [https://swapi.dev/api/people/47/]
# 16                 [https://swapi.dev/api/people/48/]
# 17                 [https://swapi.dev/api/people/49/]
# 18                 [https://swapi.dev/api/people/50/]
# 19                 [https://swapi.dev/api/people/52/]
# 20                 [https://swapi.dev/api/people/53/]
# 21  [https://swapi.dev/api/people/44/, https://swa...
# 22                 [https://swapi.dev/api/people/55/]
# 23                 [https://swapi.dev/api/people/56/]
# 24                 [https://swapi.dev/api/people/57/]
# 25                 [https://swapi.dev/api/people/58/]
# 26                 [https://swapi.dev/api/people/59/]
# 27                 [https://swapi.dev/api/people/63/]
# 28  [https://swapi.dev/api/people/64/, https://swa...
# 29                 [https://swapi.dev/api/people/70/]
# 30                 [https://swapi.dev/api/people/71/]
# 31  [https://swapi.dev/api/people/72/, https://swa...
# 32                 [https://swapi.dev/api/people/76/]
# 33                 [https://swapi.dev/api/people/77/]
# 34                 [https://swapi.dev/api/people/78/]
# 35                 [https://swapi.dev/api/people/79/]
# 36                 [https://swapi.dev/api/people/83/]
#
#                                                 films  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2   [https://swapi.dev/api/films/1/, https://swapi...
# 3                    [https://swapi.dev/api/films/1/]
# 4   [https://swapi.dev/api/films/1/, https://swapi...
# 5   [https://swapi.dev/api/films/2/, https://swapi...
# 6                    [https://swapi.dev/api/films/2/]
# 7                    [https://swapi.dev/api/films/3/]
# 8                    [https://swapi.dev/api/films/3/]
# 9                    [https://swapi.dev/api/films/3/]
# 10                   [https://swapi.dev/api/films/4/]
# 11  [https://swapi.dev/api/films/4/, https://swapi...
# 12  [https://swapi.dev/api/films/4/, https://swapi...
# 13                   [https://swapi.dev/api/films/4/]
# 14  [https://swapi.dev/api/films/3/, https://swapi...
# 15                   [https://swapi.dev/api/films/4/]
# 16                   [https://swapi.dev/api/films/4/]
# 17                   [https://swapi.dev/api/films/4/]
# 18  [https://swapi.dev/api/films/4/, https://swapi...
# 19  [https://swapi.dev/api/films/4/, https://swapi...
# 20                   [https://swapi.dev/api/films/4/]
# 21                   [https://swapi.dev/api/films/4/]
# 22  [https://swapi.dev/api/films/4/, https://swapi...
# 23  [https://swapi.dev/api/films/4/, https://swapi...
# 24  [https://swapi.dev/api/films/4/, https://swapi...
# 25  [https://swapi.dev/api/films/4/, https://swapi...
# 26  [https://swapi.dev/api/films/4/, https://swapi...
# 27  [https://swapi.dev/api/films/5/, https://swapi...
# 28  [https://swapi.dev/api/films/5/, https://swapi...
# 29  [https://swapi.dev/api/films/5/, https://swapi...
# 30                   [https://swapi.dev/api/films/5/]
# 31                   [https://swapi.dev/api/films/5/]
# 32  [https://swapi.dev/api/films/5/, https://swapi...
# 33  [https://swapi.dev/api/films/5/, https://swapi...
# 34  [https://swapi.dev/api/films/5/, https://swapi...
# 35                   [https://swapi.dev/api/films/6/]
# 36                   [https://swapi.dev/api/films/6/]
#
#                         created                       edited  \
# 0   2014-12-10T13:52:11.567000Z  2014-12-20T21:36:42.136000Z
# 1   2014-12-10T15:16:16.259000Z  2014-12-20T21:36:42.139000Z
# 2   2014-12-10T16:44:31.486000Z  2014-12-20T21:36:42.142000Z
# 3   2014-12-10T17:05:26.471000Z  2014-12-20T21:36:42.144000Z
# 4   2014-12-10T17:12:50.410000Z  2014-12-20T21:36:42.146000Z
# 5   2014-12-15T12:27:22.877000Z  2014-12-20T21:36:42.148000Z
# 6   2014-12-15T13:07:47.704000Z  2014-12-20T21:36:42.151000Z
# 7   2014-12-18T11:09:52.263000Z  2014-12-20T21:36:42.153000Z
# 8   2014-12-18T11:22:00.285000Z  2014-12-20T21:36:42.155000Z
# 9   2014-12-18T11:26:20.103000Z  2014-12-20T21:36:42.157000Z
# 10  2014-12-19T17:07:31.319000Z  2014-12-20T21:36:42.160000Z
# 11  2014-12-19T17:30:37.341000Z  2014-12-20T21:36:42.163000Z
# 12  2014-12-19T17:48:56.893000Z  2014-12-20T21:36:42.165000Z
# 13  2014-12-19T17:53:11.214000Z  2014-12-20T21:36:42.167000Z
# 14  2014-12-20T09:48:02.406000Z  2014-12-20T21:36:42.169000Z
# 15  2014-12-20T09:53:16.481000Z  2014-12-20T21:36:42.171000Z
# 16  2014-12-20T09:57:33.128000Z  2014-12-20T21:36:42.173000Z
# 17  2014-12-20T10:02:13.915000Z  2014-12-20T21:36:42.175000Z
# 18  2014-12-20T10:08:36.795000Z  2014-12-20T21:36:42.177000Z
# 19  2014-12-20T10:15:33.765000Z  2014-12-20T21:36:42.179000Z
# 20  2014-12-20T10:18:58.610000Z  2014-12-20T21:36:42.181000Z
# 21  2014-12-20T10:26:59.894000Z  2014-12-20T21:36:42.183000Z
# 22  2014-12-20T10:29:13.798000Z  2014-12-20T21:36:42.186000Z
# 23  2014-12-20T10:32:13.046000Z  2014-12-20T21:36:42.188000Z
# 24  2014-12-20T10:34:50.827000Z  2014-12-20T21:36:42.189000Z
# 25  2014-12-20T10:49:21.692000Z  2014-12-20T21:36:42.191000Z
# 26  2014-12-20T10:53:28.795000Z  2014-12-20T21:36:42.193000Z
# 27  2014-12-20T16:40:45.618000Z  2014-12-20T21:36:42.195000Z
# 28  2014-12-20T16:46:48.290000Z  2014-12-20T21:36:42.197000Z
# 29  2014-12-20T16:57:46.171000Z  2014-12-20T21:36:42.199000Z
# 30  2014-12-20T17:28:28.821000Z  2014-12-20T21:36:42.200000Z
# 31  2014-12-20T17:31:24.838000Z  2014-12-20T21:36:42.202000Z
# 32  2014-12-20T17:53:54.515000Z  2014-12-20T21:36:42.204000Z
# 33  2014-12-20T17:58:19.088000Z  2014-12-20T21:36:42.207000Z
# 34  2014-12-20T18:44:03.246000Z  2014-12-20T21:36:42.209000Z
# 35  2014-12-20T19:45:42.537000Z  2014-12-20T21:36:42.210000Z
# 36  2014-12-20T20:35:06.777000Z  2014-12-20T21:36:42.212000Z
#
#                                   url  skin_colors_num  hair_colors_num
# 0    https://swapi.dev/api/species/1/                4                4
# 1    https://swapi.dev/api/species/2/                1                1
# 2    https://swapi.dev/api/species/3/                1                2
# 3    https://swapi.dev/api/species/4/                2                1
# 4    https://swapi.dev/api/species/5/                3                1
# 5    https://swapi.dev/api/species/6/                2                2
# 6    https://swapi.dev/api/species/7/                2                1
# 7    https://swapi.dev/api/species/8/                4                1
# 8    https://swapi.dev/api/species/9/                1                3
# 9   https://swapi.dev/api/species/10/                1                1
# 10  https://swapi.dev/api/species/11/                2                1
# 11  https://swapi.dev/api/species/12/                2                1
# 12  https://swapi.dev/api/species/13/                3                1
# 13  https://swapi.dev/api/species/14/                4                1
# 14  https://swapi.dev/api/species/15/                7                1
# 15  https://swapi.dev/api/species/16/                2                1
# 16  https://swapi.dev/api/species/17/                1                1
# 17  https://swapi.dev/api/species/18/                3                1
# 18  https://swapi.dev/api/species/19/                3                1
# 19  https://swapi.dev/api/species/20/                1                4
# 20  https://swapi.dev/api/species/21/                4                1
# 21  https://swapi.dev/api/species/22/                5                1
# 22  https://swapi.dev/api/species/23/                1                1
# 23  https://swapi.dev/api/species/24/                1                1
# 24  https://swapi.dev/api/species/25/                1                1
# 25  https://swapi.dev/api/species/26/                3                1
# 26  https://swapi.dev/api/species/27/                1                1
# 27  https://swapi.dev/api/species/28/                2                1
# 28  https://swapi.dev/api/species/29/                2                2
# 29  https://swapi.dev/api/species/30/                2                1
# 30  https://swapi.dev/api/species/31/                1                1
# 31  https://swapi.dev/api/species/32/                2                1
# 32  https://swapi.dev/api/species/33/                2                1
# 33  https://swapi.dev/api/species/34/                2                1
# 34  https://swapi.dev/api/species/35/                6                1
# 35  https://swapi.dev/api/species/36/                3                1
# 36  https://swapi.dev/api/species/37/                1                1

# %%
def make_big(x):
    return x.upper()

# %%
# using apply write Name in capital letters
species[['NAME_CAPS']] = species[['name']].applymap(make_big)
species.head()
# Out:
#      name classification designation designation_group average_height  \
# 0   Human         mammal    sentient           group_1            180
# 1   Droid     artificial    sentient           group_1           None
# 2  Wookie         mammal    sentient           group_1            210
# 3  Rodian       sentient   reptilian           group_2            170
# 4    Hutt      gastropod    sentient           group_1            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                               None                       None
# 2                               gray               black, brown
# 3                        green, blue                       None
# 4                  green, brown, tan                       None
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                     None             None
# 2  blue, green, yellow, brown, golden, red              400
# 3                                    black             None
# 4                              yellow, red             1000
#
#                            homeworld        language NAME_CAPS
# 0   https://swapi.dev/api/planets/9/  Galactic Basic     HUMAN
# 1                               None            None     DROID
# 2  https://swapi.dev/api/planets/14/      Shyriiwook    WOOKIE
# 3  https://swapi.dev/api/planets/23/   Galatic Basic    RODIAN
# 4  https://swapi.dev/api/planets/24/         Huttese      HUTT

# %%
# All values of classification species
species[['classification']].value_counts()
# Out:
# classification
# mammal            16
# amphibian          6
# unknown            6
# reptile            3
# artificial         1
# gastropod          1
# insectoid          1
# mammals            1
# reptilian          1
# sentient           1
# dtype: int64

# %%
# kind of designation
species[['designation']].value_counts()
# Out:
# designation
# sentient       36
# reptilian       1
# dtype: int64

# %%
# Most popular height
species[['average_height']].value_counts()
# Out:
# average_height
# 180               10
# 200                4
# 190                4
# 100                3
# 170                2
# 178                2
# unknown            2
# 160                1
# 125                1
# 120                1
# 210                1
# 220                1
# 240                1
# 300                1
# 66                 1
# 80                 1
# n/a                1
# dtype: int64

# %%
species[['average_lifespan']].value_counts()
# Out:
# average_lifespan
# unknown             20
# 70                   3
# 80                   2
# 100                  1
# 1000                 1
# 120                  1
# 400                  1
# 700                  1
# 75                   1
# 79                   1
# 86                   1
# 900                  1
# 91                   1
# 94                   1
# indefinite           1
# dtype: int64

# %% [markdown]
# Vehicles

# %%
vehicles = get_full_type_data('http://swapi.dev/api/vehicles/')
print("Number of vehicles",vehicles.shape[0])
# Out:
# Number of vehicles 39

# %%
vehicles.columns
# Out:
# Index(['name', 'model', 'manufacturer', 'cost_in_credits', 'length',
#        'max_atmosphering_speed', 'crew', 'passengers', 'cargo_capacity',
#        'consumables', 'vehicle_class', 'pilots', 'films', 'created', 'edited',
#        'url'],
#       dtype='object')

# %%
vehicles.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer cost_in_credits length max_atmosphering_speed  \
# 0  Corellia Mining Corporation          150000  36.8                      30
# 1            Incom Corporation           14500  10.4                    1200
# 2         SoroSuub Corporation           10550   3.4                     250
# 3         Sienar Fleet Systems         unknown    6.4                   1200
# 4            Incom corporation         unknown    4.5                    650
#
#   crew passengers cargo_capacity consumables  vehicle_class  \
# 0   46         30          50000    2 months        wheeled
# 1    1          1             50           0  repulsorcraft
# 2    1          1              5     unknown  repulsorcraft
# 3    1          0             65      2 days    starfighter
# 4    2          0             10        none     airspeeder
#
#                                               pilots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [https://swapi.dev/api/people/1/, https://swap...
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1                   [https://swapi.dev/api/films/1/]
# 2                   [https://swapi.dev/api/films/1/]
# 3  [https://swapi.dev/api/films/1/, https://swapi...
# 4                   [https://swapi.dev/api/films/2/]
#
#                        created                       edited  \
# 0  2014-12-10T15:36:25.724000Z  2014-12-20T21:30:21.661000Z
# 1  2014-12-10T16:01:52.434000Z  2014-12-20T21:30:21.665000Z
# 2  2014-12-10T16:13:52.586000Z  2014-12-20T21:30:21.668000Z
# 3  2014-12-10T16:33:52.860000Z  2014-12-20T21:30:21.670000Z
# 4         2014-12-15T12:22:12Z  2014-12-20T21:30:21.672000Z
#
#                                   url
# 0   https://swapi.dev/api/vehicles/4/
# 1   https://swapi.dev/api/vehicles/6/
# 2   https://swapi.dev/api/vehicles/7/
# 3   https://swapi.dev/api/vehicles/8/
# 4  https://swapi.dev/api/vehicles/14/

# %%
# Collect unnecessary columns
column_to_drop = ['pilots','films','created','edited','url']
# Drop unnecessary columns
vehicles.drop(column_to_drop, inplace=True, axis=1)

# %%
# cleaning_empty_cells(starships)
missing_values = ['??','X','999999', 'unknown', 'indefinite', 'n/a']
for val in missing_values:
    vehicles = vehicles.replace(val, None)

starships
# Out:
#                              name                                     model  \
# 0                   CR90 corvette                             CR90 corvette
# 1                  Star Destroyer           Imperial I-class Star Destroyer
# 2    Sentinel-class landing craft              Sentinel-class landing craft
# 3                      Death Star               DS-1 Orbital Battle Station
# 4               Millennium Falcon                   YT-1300 light freighter
# 5                          Y-wing                                BTL Y-wing
# 6                          X-wing                               T-65 X-wing
# 7                 TIE Advanced x1               Twin Ion Engine Advanced x1
# 8                        Executor           Executor-class star dreadnought
# 9                 Rebel transport                    GR-75 medium transport
# 10                        Slave 1      Firespray-31-class patrol and attack
# 11               Imperial shuttle                 Lambda-class T-4a shuttle
# 12  EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 13               Calamari Cruiser            MC80 Liberty type Star Cruiser
# 14                         A-wing                   RZ-1 A-wing Interceptor
# 15                         B-wing                A/SF-01 B-wing starfighter
# 16               Republic Cruiser                    Consular-class cruiser
# 17             Droid control ship        Lucrehulk-class Droid Control Ship
# 18                  Naboo fighter                           N-1 starfighter
# 19           Naboo Royal Starship          J-type 327 Nubian royal starship
# 20                       Scimitar                              Star Courier
# 21        J-type diplomatic barge                   J-type diplomatic barge
# 22       AA-9 Coruscant freighter              Botajef AA-9 Freighter-Liner
# 23               Jedi starfighter    Delta-7 Aethersprite-class interceptor
# 24            H-type Nubian yacht                       H-type Nubian yacht
# 25          Republic Assault ship           Acclamator I-class assault ship
# 26                   Solar Sailer    Punworcca 116-class interstellar sloop
# 27       Trade Federation cruiser        Providence-class carrier/destroyer
# 28       Theta-class T-2c shuttle                  Theta-class T-2c shuttle
# 29        Republic attack cruiser              Senator-class Star Destroyer
# 30               Naboo star skiff                         J-type star skiff
# 31               Jedi Interceptor       Eta-2 Actis-class light interceptor
# 32                        arc-170  Aggressive Reconnaissance-170 starfighte
# 33            Banking clan frigte             Munificent-class star frigate
# 34       Belbullab-22 starfighter                  Belbullab-22 starfighter
# 35                         V-wing   Alpha-3 Nimbus-class V-wing starfighter
#
#                                          manufacturer cost_in_credits  length  \
# 0                   corellian engineering corporation         3500000     150
# 1                                    kuat drive yards       150000000   1,600
# 2             sienar fleet systems, cyngus spaceworks          240000      38
# 3   imperial department of military research, sien...   1000000000000  120000
# 4                   corellian engineering corporation          100000   34.37
# 5                              koensayr manufacturing          134999      14
# 6                                   incom corporation          149999    12.5
# 7                                sienar fleet systems            None     9.2
# 8                  kuat drive yards, fondor shipyards      1143350000   19000
# 9                               gallofree yards, inc.            None      90
# 10                           kuat systems engineering            None    21.5
# 11                               sienar fleet systems          240000      20
# 12                                   kuat drive yards         8500000     300
# 13                             mon calamari shipyards       104000000    1200
# 14  alliance underground engineering, incom corpor...          175000     9.6
# 15                                     slayn & korpil          220000    16.9
# 16                  corellian engineering corporation            None     115
# 17                         hoersch-kessel drive, inc.            None    3170
# 18        theed palace space vessel engineering corps          200000      11
# 19  theed palace space vessel engineering corps, n...            None      76
# 20                            republic sienar systems        55000000    26.5
# 21  theed palace space vessel engineering corps, n...         2000000      39
# 22                                  botajef shipyards            None     390
# 23                           kuat systems engineering          180000       8
# 24        theed palace space vessel engineering corps            None    47.9
# 25                          rothana heavy engineering            None     752
# 26            huppla pasa tisc shipwrights collective           35700    15.2
# 27  rendili stardrive, free dac volunteers enginee...       125000000    1088
# 28                                  cygnus spaceworks         1000000    18.5
# 29          kuat drive yards, allanteen six shipyards        59000000    1137
# 30  theed palace space vessel engineering corps/nu...            None    29.2
# 31                           kuat systems engineering          320000    5.47
# 32              incom corporation, subpro corporation          155000    14.5
# 33  hoersch-kessel drive, inc, gwori revolutionary...        57000000     825
# 34                 feethan ottraw scalable assemblies          168000    6.71
# 35                           kuat systems engineering          102500     7.9
#
#    max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                     950   30-165        600        3000000      1 year
# 1                     975   47,060       None       36000000     2 years
# 2                    1000        5         75         180000     1 month
# 3                    None  342,953    843,342  1000000000000     3 years
# 4                    1050        4          6         100000    2 months
# 5                  1000km        2          0            110      1 week
# 6                    1050        1          0            110      1 week
# 7                    1200        1          0            150      5 days
# 8                    None  279,144      38000      250000000     6 years
# 9                     650        6         90       19000000    6 months
# 10                   1000        1          6          70000     1 month
# 11                    850        6         20          80000    2 months
# 12                    800      854         75        6000000     2 years
# 13                   None     5400       1200           None     2 years
# 14                   1300        1          0             40      1 week
# 15                    950        1          0             45      1 week
# 16                    900        9         16           None        None
# 17                   None      175     139000     4000000000    500 days
# 18                   1100        1          0             65      7 days
# 19                    920        8       None           None        None
# 20                   1180        1          6        2500000     30 days
# 21                   2000        5         10           None      1 year
# 22                   None     None      30000           None        None
# 23                   1150        1          0             60      7 days
# 24                   8000        4       None           None        None
# 25                   None      700      16000       11250000     2 years
# 26                   1600        3         11            240      7 days
# 27                   1050      600      48247       50000000     4 years
# 28                   2000        5         16          50000     56 days
# 29                    975     7400       2000       20000000     2 years
# 30                   1050        3          3           None        None
# 31                   1500        1          0             60      2 days
# 32                   1000        3          0            110      5 days
# 33                   None      200       None       40000000     2 years
# 34                   1100        1          0            140      7 days
# 35                   1050        1          0             60    15 hours
#
#    hyperdrive_rating  MGLT                                     starship_class
# 0                2.0    60                  corellian engineering corporation
# 1                2.0    60                                   kuat drive yards
# 2                1.0    70            sienar fleet systems, cyngus spaceworks
# 3                4.0    10  imperial department of military research, sien...
# 4                0.5    75                  corellian engineering corporation
# 5                1.0    80                             koensayr manufacturing
# 6                1.0   100                                  incom corporation
# 7                1.0   105                               sienar fleet systems
# 8                2.0    40                 kuat drive yards, fondor shipyards
# 9                4.0    20                              gallofree yards, inc.
# 10               3.0    70                           kuat systems engineering
# 11               1.0    50                               sienar fleet systems
# 12               2.0    40                                   kuat drive yards
# 13               1.0    60                             mon calamari shipyards
# 14               1.0   120  alliance underground engineering, incom corpor...
# 15               2.0    91                                     slayn & korpil
# 16               2.0  None                  corellian engineering corporation
# 17               2.0  None                         hoersch-kessel drive, inc.
# 18               1.0  None        theed palace space vessel engineering corps
# 19               1.8  None  theed palace space vessel engineering corps, n...
# 20               1.5  None                            republic sienar systems
# 21               0.7  None  theed palace space vessel engineering corps, n...
# 22              None  None                                  botajef shipyards
# 23               1.0  None                           kuat systems engineering
# 24               0.9  None        theed palace space vessel engineering corps
# 25               0.6  None                          rothana heavy engineering
# 26               1.5  None            huppla pasa tisc shipwrights collective
# 27               1.5  None  rendili stardrive, free dac volunteers enginee...
# 28               1.0  None                                  cygnus spaceworks
# 29               1.0  None          kuat drive yards, allanteen six shipyards
# 30               0.5  None  theed palace space vessel engineering corps/nu...
# 31               1.0  None                           kuat systems engineering
# 32               1.0   100              incom corporation, subpro corporation
# 33               1.0  None  hoersch-kessel drive, inc, gwori revolutionary...
# 34                 6  None                 feethan ottraw scalable assemblies
# 35               1.0  None                           kuat systems engineering

# %%
# correct manufacturer data into low letters
column = 'manufacturer'
vehicles[column] = vehicles[column].str.lower()
vehicles.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer cost_in_credits length max_atmosphering_speed  \
# 0  corellia mining corporation          150000  36.8                      30
# 1            incom corporation           14500  10.4                    1200
# 2         sorosuub corporation           10550   3.4                     250
# 3         sienar fleet systems            None    6.4                   1200
# 4            incom corporation            None    4.5                    650
#
#   crew passengers cargo_capacity consumables  vehicle_class
# 0   46         30          50000    2 months        wheeled
# 1    1          1             50           0  repulsorcraft
# 2    1          1              5        None  repulsorcraft
# 3    1          0             65      2 days    starfighter
# 4    2          0             10        none     airspeeder

# %%
column = 'manufacturer'
vehicles[[column]].value_counts()
# Out:
# manufacturer
# baktoid armor workshop                                        3
# sienar fleet systems                                          3
# rothana heavy engineering                                     3
# appazanna engineering works                                   2
# haor chall engineering                                        2
# kuat drive yards                                              2
# incom corporation                                             2
# huppla pasa tisc shipwrights collective                       2
# kuat drive yards, imperial department of military research    2
# haor chall engineering, baktoid armor workshop                1
# desler gizh outworld mobility corporation                     1
# unknown                                                       1
# ubrikkian industries custom vehicle division                  1
# ubrikkian industries                                          1
# techno union                                                  1
# sorosuub corporation                                          1
# baktoid fleet ordnance, haor chall engineering                1
# rothana heavy engineering, kuat drive yards                   1
# bespin motors                                                 1
# razalon                                                       1
# otoh gunga bongameken cooperative                             1
# narglatch airtech prefabricated kit                           1
# mobquet swoops and speeders                                   1
# aratech repulsor company                                      1
# colla designs, phlac-arphocc automata industries              1
# corellia mining corporation                                   1
# z-gomot ternbuell guppat corporation                          1
# dtype: int64

# %% [markdown]
# Starships

# %%
starships = get_full_type_data('http://swapi.dev/api/starships/')
print("Number of starships",starships.shape[0])
# Out:
# Number of starships 36

# %%
starships.columns
# Out:
# Index(['name', 'model', 'manufacturer', 'cost_in_credits', 'length',
#        'max_atmosphering_speed', 'crew', 'passengers', 'cargo_capacity',
#        'consumables', 'hyperdrive_rating', 'MGLT', 'starship_class', 'pilots',
#        'films', 'created', 'edited', 'url'],
#       dtype='object')

# %%
starships.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                    950   30-165        600        3000000      1 year
# 1                    975   47,060        n/a       36000000     2 years
# 2                   1000        5         75         180000     1 month
# 3                    n/a  342,953    843,342  1000000000000     3 years
# 4                   1050        4          6         100000    2 months
#
#   hyperdrive_rating MGLT                   starship_class  \
# 0               2.0   60                         corvette
# 1               2.0   60                   Star Destroyer
# 2               1.0   70                    landing craft
# 3               4.0   10  Deep Space Mobile Battlestation
# 4               0.5   75                  Light freighter
#
#                                               pilots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [https://swapi.dev/api/people/13/, https://swa...
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2                   [https://swapi.dev/api/films/1/]
# 3                   [https://swapi.dev/api/films/1/]
# 4  [https://swapi.dev/api/films/1/, https://swapi...
#
#                        created                       edited  \
# 0  2014-12-10T14:20:33.369000Z  2014-12-20T21:23:49.867000Z
# 1  2014-12-10T15:08:19.848000Z  2014-12-20T21:23:49.870000Z
# 2  2014-12-10T15:48:00.586000Z  2014-12-20T21:23:49.873000Z
# 3  2014-12-10T16:36:50.509000Z  2014-12-20T21:26:24.783000Z
# 4  2014-12-10T16:59:45.094000Z  2014-12-20T21:23:49.880000Z
#
#                                    url
# 0   https://swapi.dev/api/starships/2/
# 1   https://swapi.dev/api/starships/3/
# 2   https://swapi.dev/api/starships/5/
# 3   https://swapi.dev/api/starships/9/
# 4  https://swapi.dev/api/starships/10/

# %%
# cleaning_empty_cells(starships)
missing_values = ['??','X','999999', 'unknown', 'indefinite', 'n/a']
for val in missing_values:
    starships = starships.replace(val, None)

starships.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  corellian engineering corporation         3500000     150
# 1                                   kuat drive yards       150000000   1,600
# 2            sienar fleet systems, cyngus spaceworks          240000      38
# 3  imperial department of military research, sien...   1000000000000  120000
# 4                  corellian engineering corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                    950   30-165        600        3000000      1 year
# 1                    975   47,060       None       36000000     2 years
# 2                   1000        5         75         180000     1 month
# 3                   None  342,953    843,342  1000000000000     3 years
# 4                   1050        4          6         100000    2 months
#
#   hyperdrive_rating MGLT                                     starship_class
# 0               2.0   60                  corellian engineering corporation
# 1               2.0   60                                   kuat drive yards
# 2               1.0   70            sienar fleet systems, cyngus spaceworks
# 3               4.0   10  imperial department of military research, sien...
# 4               0.5   75                  corellian engineering corporation

# %%
# correct manufacturer data into low letters
starships['manufacturer'] = starships[column].str.lower()
starships['starship_class'] = starships[column].str.lower()
starships.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  corellian engineering corporation         3500000     150
# 1                                   kuat drive yards       150000000   1,600
# 2            sienar fleet systems, cyngus spaceworks          240000      38
# 3  imperial department of military research, sien...   1000000000000  120000
# 4                  corellian engineering corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                    950   30-165        600        3000000      1 year
# 1                    975   47,060       None       36000000     2 years
# 2                   1000        5         75         180000     1 month
# 3                   None  342,953    843,342  1000000000000     3 years
# 4                   1050        4          6         100000    2 months
#
#   hyperdrive_rating MGLT                                     starship_class  \
# 0               2.0   60                  corellian engineering corporation
# 1               2.0   60                                   kuat drive yards
# 2               1.0   70            sienar fleet systems, cyngus spaceworks
# 3               4.0   10  imperial department of military research, sien...
# 4               0.5   75                  corellian engineering corporation
#
#                                               pilots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [https://swapi.dev/api/people/13/, https://swa...
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2                   [https://swapi.dev/api/films/1/]
# 3                   [https://swapi.dev/api/films/1/]
# 4  [https://swapi.dev/api/films/1/, https://swapi...
#
#                        created                       edited  \
# 0  2014-12-10T14:20:33.369000Z  2014-12-20T21:23:49.867000Z
# 1  2014-12-10T15:08:19.848000Z  2014-12-20T21:23:49.870000Z
# 2  2014-12-10T15:48:00.586000Z  2014-12-20T21:23:49.873000Z
# 3  2014-12-10T16:36:50.509000Z  2014-12-20T21:26:24.783000Z
# 4  2014-12-10T16:59:45.094000Z  2014-12-20T21:23:49.880000Z
#
#                                    url
# 0   https://swapi.dev/api/starships/2/
# 1   https://swapi.dev/api/starships/3/
# 2   https://swapi.dev/api/starships/5/
# 3   https://swapi.dev/api/starships/9/
# 4  https://swapi.dev/api/starships/10/

# %%
bcolumn = 'starship_class'
starships[column].value_counts()
# Out:
# kuat systems engineering                                                       4
# corellian engineering corporation                                              3
# sienar fleet systems                                                           2
# kuat drive yards                                                               2
# theed palace space vessel engineering corps                                    2
# theed palace space vessel engineering corps, nubia star drives                 2
# republic sienar systems                                                        1
# hoersch-kessel drive, inc, gwori revolutionary industries                      1
# incom corporation, subpro corporation                                          1
# theed palace space vessel engineering corps/nubia star drives, incorporated    1
# kuat drive yards, allanteen six shipyards                                      1
# cygnus spaceworks                                                              1
# rendili stardrive, free dac volunteers engineering corps.                      1
# huppla pasa tisc shipwrights collective                                        1
# rothana heavy engineering                                                      1
# botajef shipyards                                                              1
# hoersch-kessel drive, inc.                                                     1
# slayn & korpil                                                                 1
# alliance underground engineering, incom corporation                            1
# mon calamari shipyards                                                         1
# gallofree yards, inc.                                                          1
# kuat drive yards, fondor shipyards                                             1
# incom corporation                                                              1
# koensayr manufacturing                                                         1
# imperial department of military research, sienar fleet systems                 1
# sienar fleet systems, cyngus spaceworks                                        1
# feethan ottraw scalable assemblies                                             1
# Name: manufacturer, dtype: int64

# %%
column = 'manufacturer'
starships[column].value_counts()
# Out:
# kuat systems engineering                                                       4
# corellian engineering corporation                                              3
# sienar fleet systems                                                           2
# kuat drive yards                                                               2
# theed palace space vessel engineering corps                                    2
# theed palace space vessel engineering corps, nubia star drives                 2
# republic sienar systems                                                        1
# hoersch-kessel drive, inc, gwori revolutionary industries                      1
# incom corporation, subpro corporation                                          1
# theed palace space vessel engineering corps/nubia star drives, incorporated    1
# kuat drive yards, allanteen six shipyards                                      1
# cygnus spaceworks                                                              1
# rendili stardrive, free dac volunteers engineering corps.                      1
# huppla pasa tisc shipwrights collective                                        1
# rothana heavy engineering                                                      1
# botajef shipyards                                                              1
# hoersch-kessel drive, inc.                                                     1
# slayn & korpil                                                                 1
# alliance underground engineering, incom corporation                            1
# mon calamari shipyards                                                         1
# gallofree yards, inc.                                                          1
# kuat drive yards, fondor shipyards                                             1
# incom corporation                                                              1
# koensayr manufacturing                                                         1
# imperial department of military research, sienar fleet systems                 1
# sienar fleet systems, cyngus spaceworks                                        1
# feethan ottraw scalable assemblies                                             1
# Name: manufacturer, dtype: int64

# %%
# Collect unnecessary columns
column_to_drop = ['pilots','films','created','edited','url']

# %%
# Drop unnecessary columns
starships.drop(column_to_drop, inplace=True, axis=1)

# %%
starships.tail()
# Out:
#                         name                                     model  \
# 31          Jedi Interceptor       Eta-2 Actis-class light interceptor
# 32                   arc-170  Aggressive Reconnaissance-170 starfighte
# 33       Banking clan frigte             Munificent-class star frigate
# 34  Belbullab-22 starfighter                  Belbullab-22 starfighter
# 35                    V-wing   Alpha-3 Nimbus-class V-wing starfighter
#
#                                          manufacturer cost_in_credits length  \
# 31                           kuat systems engineering          320000   5.47
# 32              incom corporation, subpro corporation          155000   14.5
# 33  hoersch-kessel drive, inc, gwori revolutionary...        57000000    825
# 34                 feethan ottraw scalable assemblies          168000   6.71
# 35                           kuat systems engineering          102500    7.9
#
#    max_atmosphering_speed crew passengers cargo_capacity consumables  \
# 31                   1500    1          0             60      2 days
# 32                   1000    3          0            110      5 days
# 33                   None  200       None       40000000     2 years
# 34                   1100    1          0            140      7 days
# 35                   1050    1          0             60    15 hours
#
#    hyperdrive_rating  MGLT starship_class
# 31               1.0  None    starfighter
# 32               1.0   100    starfighter
# 33               1.0  None        cruiser
# 34                 6  None    starfighter
# 35               1.0  None    starfighter
