# %%
import pandas as pd
import requests
import datetime

# %%
# Function to check if url is correct
def api_connection(url):
    my_request = requests.get(url)
    if my_request:
#         print(my_request, "Connected")
        data = my_request.json() # Data from api if api is correct
    else:
#         print(my_request, "can't connect to api")
        data = None
    return data

# %%
# API for project
url = 'https://swapi.dev/api/'
data = api_connection(url)

# %%
# data

# %%
data.keys()
# Out:
# dict_keys(['people', 'planets', 'films', 'species', 'vehicles', 'starships'])

# %%
data.values()
# Out:
# dict_values(['https://swapi.dev/api/people/', 'https://swapi.dev/api/planets/', 'https://swapi.dev/api/films/', 'https://swapi.dev/api/species/', 'https://swapi.dev/api/vehicles/', 'https://swapi.dev/api/starships/'])

# %%
link_people = data['people']
data_people = api_connection(link_people)
data_people
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
for i in data_people:
    link_next = data_people['next']
    print(link_next)
    data_people = api_connection(link_next)
    data_people
# Out:
# https://swapi.dev/api/people/?page=2
# https://swapi.dev/api/people/?page=3
# https://swapi.dev/api/people/?page=4
# https://swapi.dev/api/people/?page=5

# %%
df_people = pd.json_normalize(data_people['results']) 
df_people
# Out:
#              name height     mass hair_color           skin_color eye_color  \
# 0   Quarsh Panaka    183  unknown      black                 dark     brown
# 1  Shmi Skywalker    163  unknown      black                 fair     brown
# 2      Darth Maul    175       80       none                  red    yellow
# 3     Bib Fortuna    180  unknown       none                 pale      pink
# 4     Ayla Secura    178       55       none                 blue     hazel
# 5    Ratts Tyerel     79       15       none           grey, blue   unknown
# 6        Dud Bolt     94       45       none           blue, grey    yellow
# 7         Gasgano    122  unknown       none          white, blue     black
# 8  Ben Quadinaros    163       65       none  grey, green, yellow    orange
# 9      Mace Windu    188       84       none                 dark     brown
#
#   birth_year  gender                          homeworld  \
# 0      62BBY    male   https://swapi.dev/api/planets/8/
# ...

# %%
df_people.describe()
# Out:
#                  name height     mass hair_color skin_color eye_color  \
# count              10     10       10         10         10        10
# unique             10      9        7          2          9         7
# top     Quarsh Panaka    163  unknown       none       dark     brown
# freq                1      2        4          8          2         3
#
#        birth_year gender                          homeworld  \
# count          10     10                                 10
# unique          5      2                                  9
# top       unknown   male  https://swapi.dev/api/planets/37/
# freq            5      8                                  2
#
#                                    films species vehicles starships  \
# count                                 10      10       10        10
# unique                                 4       7        2         2
# top     [https://swapi.dev/api/films/4/]      []       []        []
# ...

# %%
link_planets = data['planets']
data_planets = api_connection(link_planets)
# data_planets

# %%
df_planets = pd.json_normalize(data_planets['results']) 
df_planets.columns
# Out:
# Index(['name', 'rotation_period', 'orbital_period', 'diameter', 'climate',
#        'gravity', 'terrain', 'surface_water', 'population', 'residents',
#        'films', 'created', 'edited', 'url'],
#       dtype='object')

# %%
link_films = data['films']
data_films = api_connection(link_films)
# data_species

# %%
df_films = pd.json_normalize(data_films['results']) 
df_films.columns
# Out:
# Index(['title', 'episode_id', 'opening_crawl', 'director', 'producer',
#        'release_date', 'characters', 'planets', 'starships', 'vehicles',
#        'species', 'created', 'edited', 'url'],
#       dtype='object')

# %%
link_species = data['species']
data_species = api_connection(link_species)
# data_species

# %%
df_species = pd.json_normalize(data_species['results']) 
df_species #.columns
# Out:
#              name classification designation average_height  \
# 0           Human         mammal    sentient            180
# 1           Droid     artificial    sentient            n/a
# 2          Wookie         mammal    sentient            210
# 3          Rodian       sentient   reptilian            170
# 4            Hutt      gastropod    sentient            300
# 5  Yoda's species         mammal    sentient             66
# 6      Trandoshan        reptile    sentient            200
# 7    Mon Calamari      amphibian    sentient            160
# 8            Ewok         mammal    sentient            100
# 9       Sullustan         mammal    sentient            180
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                n/a                        n/a
# 2                               gray               black, brown
# ...

# %%
sw_data = dict()

for key, url in data.items():
    print(key, url)
    data = api_connection(url)
    data
# Out:
# people https://swapi.dev/api/people/
# planets https://swapi.dev/api/planets/
# films https://swapi.dev/api/films/
# species https://swapi.dev/api/species/
# vehicles https://swapi.dev/api/vehicles/
# starships https://swapi.dev/api/starships/
